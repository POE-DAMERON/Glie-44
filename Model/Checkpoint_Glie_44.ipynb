# %% [markdown]
# <a href="https://colab.research.google.com/github/POE-DAMERON/Glie-44/blob/main/Model/Checkpoint_Glie_44.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTANT!!!!!
#IF YOURE TRAINING FROM A CHECKPOINT, USE THE LAST BOX INSTEAD OF THE ONE BEFORE

import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow_hub as hub
from PIL import Image, ImageDraw, ImageFont
from os import path, listdir
from pathlib import Path
import cv2 as cv
from google.colab import drive
import sys
import io
import random


# %matplotlib inline

'''
  Downloads Data from the VisDrone dataset.
  Input is which dataset to download:
    - 0 is the training dataset
    - 1 is the developper testing dataset
    - 2 is the actual challenge testing dataset
    - 3 is the val dataset
'''

def initialize_training(file = 0):
  # !git clone https://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@github.com/POE-DAMERON/Glie-44.git
  drive.mount('/content/drive')

  
  if file == 1:
    # !unzip /content/drive/MyDrive/VisDrone2019-MOT-test-dev.zip
  elif file == 2:
    # !unzip /content/drive/MyDrive/VisDrone2019-MOT-test-challenge.zip
  elif file == 3:
    # !unzip /content/drive/MyDrive/VisDrone2019-MOT-val.zip
  else:
    # !unzip /content/drive/MyDrive/VisDrone2019-MOT-train.zip

initialize_training()
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000588.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000589.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000590.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000591.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000592.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000593.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000594.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000595.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000596.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000597.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000598.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000599.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000600.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000601.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000602.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000603.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000604.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000605.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000606.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000607.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000608.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000609.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000610.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000611.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000612.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000613.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000614.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000615.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000616.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000617.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000618.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000619.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000620.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000621.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000622.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000623.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000624.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000625.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000626.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000627.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000628.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000629.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000630.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000631.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000632.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000633.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000634.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000635.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000636.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000637.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000638.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000639.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000640.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000641.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000642.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000643.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000644.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000645.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000646.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000647.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000648.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000649.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000650.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000651.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000652.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000653.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000654.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000655.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000656.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000657.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000658.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000659.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000660.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000661.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000662.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000663.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000664.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000665.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000666.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000667.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000668.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000669.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000670.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000671.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000672.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000673.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000674.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000675.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000676.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000677.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000678.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000679.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000680.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000681.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000682.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000683.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000684.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000685.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000686.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000687.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000688.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000689.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000690.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000691.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000692.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000693.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000694.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000695.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000696.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000697.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000698.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000699.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000700.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000701.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000702.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000703.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000704.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000705.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000706.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000707.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000708.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000709.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000710.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000711.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000712.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000713.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000714.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000715.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000716.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000717.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000718.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000719.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000720.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000244_01440_v_0000721.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000001.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000002.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000003.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000004.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000005.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000006.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000007.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000008.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000009.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000010.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000011.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000012.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000013.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000014.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000015.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000016.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000017.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000018.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000019.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000020.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000021.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000022.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000023.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000024.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000025.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000026.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000027.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000028.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000029.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000030.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000031.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000032.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000033.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000034.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000035.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000036.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000037.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000038.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000039.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000040.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000041.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000042.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000043.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000044.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000045.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000046.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000047.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000048.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000049.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000050.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000051.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000052.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000053.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000054.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000055.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000056.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000057.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000058.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000059.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000060.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000061.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000062.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000063.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000064.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000065.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000066.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000067.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000068.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000069.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000070.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000071.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000072.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000073.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000074.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000075.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000076.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000077.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000078.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000079.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000080.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000081.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000082.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000083.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000084.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000085.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000086.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000087.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000088.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000089.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000090.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000091.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000092.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000093.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000094.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000095.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000096.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000097.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000098.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000099.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000100.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000101.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000102.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000103.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000104.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000105.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000106.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000107.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000108.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000109.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000110.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000111.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000112.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000113.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000114.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000115.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000116.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000117.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000118.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000119.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000120.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000121.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000122.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000123.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000124.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000125.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000126.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000127.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000128.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000129.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000130.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000131.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000132.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000133.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000134.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000135.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000136.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000137.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000138.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000139.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000140.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000141.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000142.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000143.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000144.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000145.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000146.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000147.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000148.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000149.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000150.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000151.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000152.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000153.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000154.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000155.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000156.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000157.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000158.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000159.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000160.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000161.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000162.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000163.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000164.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000165.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000166.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000167.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000168.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000169.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000170.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000171.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000172.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000173.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000174.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000175.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000176.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000177.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000178.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000179.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000180.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000181.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000182.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000183.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000184.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000185.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000186.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000187.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000188.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000189.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000190.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000191.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000192.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000193.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000194.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000195.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000196.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000197.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000198.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000199.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000200.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000201.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000202.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000203.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000204.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000205.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000206.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000207.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000208.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000209.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000210.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000211.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000212.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000213.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000214.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000215.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000216.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000217.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000218.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000219.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000220.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000221.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000222.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000223.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000224.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000225.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000226.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000227.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000228.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000229.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000230.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000231.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000232.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000233.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000234.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000235.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000236.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000237.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000238.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000239.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000240.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000241.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000242.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000243.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000244.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000245.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000246.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000247.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000248.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000249.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000250.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000251.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000252.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000253.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000254.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000255.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000256.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000257.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000258.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000259.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000260.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000261.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000262.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000263.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000264.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000265.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000266.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000267.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000268.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000269.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000270.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000271.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000272.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000273.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000274.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000275.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000276.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000277.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000278.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000279.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000280.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000281.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000282.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000283.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000284.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000285.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000286.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000287.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000288.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000289.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000290.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000291.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000292.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000293.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000294.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000295.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000296.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000297.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000298.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000299.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000300.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000301.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000302.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000303.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000304.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000305.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000306.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000307.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000308.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000309.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000310.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000311.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000312.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000313.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000314.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000315.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000316.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000317.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000318.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000319.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000320.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000321.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000322.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000323.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000324.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000325.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000326.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000327.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000328.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000329.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000330.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000331.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000332.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000333.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000334.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000335.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000336.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000337.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000338.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000339.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000340.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000341.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000342.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000343.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000344.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000345.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000346.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000347.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000348.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000349.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000350.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000351.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000352.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000353.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000354.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000355.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000356.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000357.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000358.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000359.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000360.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000361.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000362.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000363.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000364.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000365.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000366.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000367.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000368.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000369.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000370.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000371.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000372.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000373.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000374.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000375.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000376.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000377.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000378.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000379.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000380.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000381.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000382.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000383.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000384.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000385.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000386.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000387.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000388.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000389.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000390.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000391.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000392.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000393.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000394.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000395.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000396.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000397.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000398.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000399.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000400.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000401.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000402.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000403.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000404.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000405.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000406.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000407.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000408.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000409.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000410.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000411.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000412.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000413.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000414.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000415.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000416.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000417.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000418.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000419.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000420.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000421.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000422.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000423.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000424.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000425.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000426.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000427.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000428.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000429.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000430.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000431.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000432.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000433.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000434.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000435.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000436.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000437.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000438.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000439.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000440.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000441.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000442.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000443.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000444.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000445.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000446.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000447.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000448.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000449.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000450.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000451.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000452.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000453.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000454.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000455.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000456.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000457.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000458.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000459.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000460.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000461.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000462.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000463.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000464.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000465.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000466.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000467.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000468.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000469.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000470.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000471.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000248_00001_v_0000472.jpg
# ...
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000431.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000432.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000433.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000434.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000435.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000436.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000437.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000438.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000439.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000440.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000441.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000442.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000443.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000444.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000445.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000446.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000447.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000448.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000449.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000450.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000451.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000452.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000453.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000454.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000455.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000456.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000457.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000458.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000459.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000460.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000461.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000462.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000463.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000464.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000465.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000466.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000467.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000468.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000469.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000470.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000471.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000472.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000473.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000474.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000475.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000476.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000477.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000478.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000479.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000480.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000481.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000482.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000483.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000484.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000485.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000486.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000487.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000488.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000489.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000490.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000491.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000492.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000493.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000494.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000495.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000496.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000497.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000498.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000499.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000500.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000501.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000502.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000503.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000504.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000505.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000506.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000507.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000508.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000509.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000510.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000511.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000512.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000513.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000514.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000515.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000516.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000517.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000518.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000519.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000520.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000521.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000522.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000523.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000524.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000525.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000526.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000527.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000528.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000529.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000530.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000531.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000532.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000533.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000534.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000535.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000536.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000537.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000538.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000539.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000540.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000541.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000542.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000543.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000544.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000545.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000546.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000547.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000548.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000549.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000550.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000551.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000552.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000553.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000554.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000555.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000556.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000557.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000558.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000559.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000560.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000561.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000562.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000563.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000564.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000565.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000566.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000567.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000568.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000569.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000570.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000571.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000572.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000573.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000574.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000575.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000576.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000577.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000578.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000579.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000580.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000581.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000582.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000583.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000584.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000585.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000586.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000587.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000588.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000589.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000590.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000591.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000592.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000593.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000594.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000595.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000596.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000597.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000598.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000599.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000600.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000601.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000602.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000603.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000604.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000605.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000606.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000607.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000608.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000609.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000610.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000611.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000612.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000613.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000614.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000615.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000616.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000617.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000618.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000619.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000620.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000621.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000622.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000623.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000624.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000625.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000626.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000627.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000628.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000629.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000630.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000631.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000278_00001_v_0000632.jpg

# %% [markdown]
# **New Model using Pytorch**

# %% [markdown]
# Main.py

# %%
# %%shell
#
# git clone https://github.com/pytorch/vision.git
# cd vision
# git checkout v0.3.0
#
# cp references/detection/utils.py ../
# cp references/detection/transforms.py ../
# cp references/detection/coco_eval.py ../
# cp references/detection/engine.py ../
# cp references/detection/coco_utils.py ../

# %%
import torch
from engine import train_one_epoch, evaluate
import utils
import os
import pandas as pd
import transforms as T
from pathlib import Path
import csv
import time

def get_results(evaluator):
  old_stdout = sys.stdout
  sys.stdout = buffer = io.StringIO()

  result = str(evaluator.coco_eval)
  test = evaluator.coco_eval.items()
  for iou_type, coco_eval in test:
    print("IoU metric: {}".format(iou_type))
    try:
      print(coco_eval)
    except:
      pass

  sys.stdout = old_stdout

  return buffer.getvalue()

def add_to_record(arguments, output, is_saved = False, path_to_saved_model = ''):

  with open('drive/MyDrive/training.csv', 'a', newline='') as f:
    writer = csv.writer(f)

    #writer.writerow(['Saved', 'path_to_saved_model', 'number_of_epochs', 'batch_size', 'optimizer', 'learning_rate', 'weight_decay', 'momentum', 'lr_scheduler_step_size', 'lr_scheduler_gamma', 'output'])
    writer.writerow([is_saved, path_to_saved_model, arguments['number_of_epochs'], arguments['batch_size'], arguments['optimizer'], arguments['lr'], arguments['weight_decay'], arguments['momentum'], arguments['lr_scheduler_step_size'], arguments['lr_scheduler_gamma'], output])


"""
  saving the model will add it to the record
"""

def save_model(model, evaluator, arguments, path = ''):

  """
      saves the model and adds to the csv records

      2 methods :
        - saving the whole model
        - saving the weights and info
  """

  if path == '':
    path = 'drive/MyDrive/Models/model-' + str(int(time.time())) + '.pth'

  torch.save(model,path) 

  #torch.save(model.state_dict(), path)
  add_to_record(arguments = arguments, output = evaluator, is_saved = True, path_to_saved_model = path)
  
def save_checkpoint(model, epoch, arguments, path =''):
  if path == '':
    path = 'drive/MyDrive/Models/model-cp-' + str(int(time.time())) + '.tar'

  torch.save({
      'epoch': epoch,
      'model_state_dict': model.state_dict(),
      'arguments':arguments,
  },path) 
  
def load_model(path):

  model = torch.load(path)

  """
    model = Model()
    model.load_state_dict(torch.load(path))
  """

  return model

def load_checkpoint(path):

  checkpoint = torch.load(path)
  return checkpoint['model_state_dict'], checkpoint['epoch'], checkpoint['arguments']

def get_arguments(train_percentage, epochs, batch_size, optimizer,
                            lr, momentum, weight_decay, step_size, gamma):
  
  arguments = {}

  arguments['train_percentage'] = train_percentage
  if (optimizer == 'adam'):
    arguments['optimizer'] = optimizer
    arguments['momentum'] = ''
  else:
    arguments['optimizer'] = 'sgd'
    arguments['momentum'] = momentum
  arguments['lr'] = lr
  arguments['weight_decay'] = weight_decay
  arguments['lr_scheduler_step_size'] = step_size
  arguments['lr_scheduler_gamma'] = gamma
  arguments['number_of_epochs'] = epochs
  arguments['batch_size'] = batch_size

  return arguments

def train_videos(path_to_saved_model = '', train_percentage = .8, test_size = -1,
          train_size = -1, batch_size = 2, epochs = 10, optimizer='sgd',
          lr = 0.005, momentum = 0.9, weight_decay= 0.0005, step_size = 3,
          gamma = 0.1):
  
  arguments = get_arguments(train_percentage, epochs, batch_size, optimizer,
                            lr, momentum, weight_decay, step_size, gamma)
  
  if torch.cuda.is_available():
    device = torch.device('cuda')
  else:
    device = torch.device('cpu')
  
  x = VisDroneDataset(Path().absolute().joinpath('VisDrone2019-MOT-train'), Utils.to_tensor())
  testing_data = torch.utils.data.DataLoader(x[0])

  for i in range(len(x)):

    print("\n-----------------------------\nVideo {} / {}\n".format(i+1, len(x)))

    X = x[i]

    if train_size == -1:
      train_sz = int(len(X) * train_percentage)
    else:
      train_sz = train_size
      
    x_train, x_test = torch.utils.data.random_split(X, [train_sz, len(X) - train_sz])

    if test_size != -1:
      x_test = Utils.slice(x_test, 0, test_size)

    data_loader = torch.utils.data.DataLoader(
          x_train, batch_size=batch_size, shuffle=True, num_workers=2,
          collate_fn=utils.collate_fn)
    
    data_loader_test = torch.utils.data.DataLoader(
      x_test, batch_size=1, shuffle=False, num_workers=2,
      collate_fn=utils.collate_fn)
    
    testing_data = data_loader_test
    
    if str(path_to_saved_model) == '':
      model = build_model()
    else:
      model = load_model(path_to_saved_model)

    model.to(device)

    params = [p for p in model.parameters() if p.requires_grad]

    if (optimizer == 'adam'):
      optim = torch.optim.Adam(params, lr=lr, weight_decay=weight_decay)
    else:
      optim = torch.optim.SGD(params, lr=lr,
                              momentum=momentum, weight_decay=weight_decay)

    lr_scheduler = torch.optim.lr_scheduler.StepLR(optim,
                                                    step_size=step_size,
                                                    gamma=gamma)

    for epoch in range(epochs):
          train_one_epoch(model, optim, data_loader, device, epoch, print_freq=10)
          lr_scheduler.step()
          evaluate(model, testing_data, device=device)
  
  return model, evaluate(model, testing_data, device=device), arguments

def train(model, train_percentage = .8, test_percentage = -1,
          test_size = -1, train_size = -1, batch_size = 2, epochs = 10, optimizer='sgd',
          lr = 0.005, momentum = 0.9, weight_decay= 0.0005, step_size = 3,
          gamma = 0.1, checkpoints=-1, cur_epoch = 0):
  
  arguments = get_arguments(train_percentage, epochs, batch_size, optimizer,
                            lr, momentum, weight_decay, step_size, gamma)
  
  if torch.cuda.is_available():
    device = torch.device('cuda')
  else:
    device = torch.device('cpu')
  
  X = AllVisDroneVideos(Path().absolute().joinpath('VisDrone2019-MOT-train').joinpath("sequences"), Path().absolute().joinpath('VisDrone2019-MOT-train').joinpath("annotations"), Utils.to_tensor())

  if train_size == -1:
    train_sz = int(len(X) * train_percentage)
  else:
    train_sz = train_size
  
  test_sz = int(len(X) * min(1,max(0, test_percentage)))

  x_train, x_test, x_overflow = torch.utils.data.random_split(X, [train_sz, test_sz , len(X) - train_sz - test_sz])

  random.shuffle(X.imgs)

  x_train = AllVisDroneVideos(Path().absolute().joinpath('VisDrone2019-MOT-train').joinpath("sequences"), Path().absolute().joinpath('VisDrone2019-MOT-train').joinpath("annotations"), Utils.to_tensor(), X.imgs[:train_sz])
  x_test = AllVisDroneVideos(Path().absolute().joinpath('VisDrone2019-MOT-train').joinpath("sequences"), Path().absolute().joinpath('VisDrone2019-MOT-train').joinpath("annotations"), Utils.to_tensor(), X.imgs[train_sz:train_sz + test_sz])

  if test_size != -1:
    x_test = Utils.slice(x_test, 0, test_size)

  data_loader = torch.utils.data.DataLoader(
      x_train, batch_size=batch_size, shuffle=True, num_workers=2,
      collate_fn=utils.collate_fn)
    
  data_loader_test = torch.utils.data.DataLoader(
      x_test, batch_size=1, shuffle=False, num_workers=2,
      collate_fn=utils.collate_fn)

  """  
  if str(path_to_saved_model) == '':
    model = build_model()
  else:
    model = load_model(path_to_saved_model)
  """
  model.to(device)

  params = [p for p in model.parameters() if p.requires_grad]

  if (optimizer == 'adam'):
    optim = torch.optim.Adam(params, lr=lr, weight_decay=weight_decay)
  else:
    optim = torch.optim.SGD(params, lr=lr,
                              momentum=momentum, weight_decay=weight_decay)

  lr_scheduler = torch.optim.lr_scheduler.StepLR(optim,
                                                    step_size=step_size,
                                                    gamma=gamma)

  for epoch in range(cur_epoch, epochs):
    train_one_epoch(model, optim, data_loader, device, epoch, print_freq=10)
    print('\n---------\nTRAIN ONE EPOCH FINISHED')
    lr_scheduler.step()
    evaluate(model, data_loader_test, device=device)
    results = get_results(evaluate(model, data_loader_test, device=device))
    if checkpoints != -1 and epoch % checkpoints == 0:
      save_checkpoint(model, epoch, arguments, path_to_saved_model)
      print('\nCheckpoint Saved\n')
  
  return model, results, arguments

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator

def build_model(num_classes = 12):
  model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
  in_features = model.roi_heads.box_predictor.cls_score.in_features
  model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

  """
  backbone = torchvision.models.mobilenet_v2(pretrained=True).features
  backbone.out_channels = 1280

  anchor_generator = AnchorGenerator(sizes=((32, 64, 128, 256, 512),),
                                    aspect_ratios=((0.5, 1.0, 2.0),))

  roi_pooler = torchvision.ops.MultiScaleRoIAlign(featmap_names=['0'],
                                                  output_size=7,
                                                  sampling_ratio=2)
  return FasterRCNN(backbone,
                    num_classes=num_classes,
                    rpn_anchor_generator=anchor_generator,
                    box_roi_pool=roi_pooler)
  """
  return model

# %%
class VisDroneVideo(object):
    def __init__(self ,root, target_path, preprocessing = None, imgs = None):
        self.root = str(root)
        self.preprocessing = preprocessing
        if (imgs != None):
          self.imgs = imgs
        else:
          self.imgs = sorted(listdir(Path(root)), key=lambda x: x.lstrip("_"))
        self.target = target_path

    def __getitem__(self, idx):

        img_path = Path(self.root).joinpath(self.imgs[idx])
        img = Image.open(img_path).convert("RGB")

        video_targets = Utils.read_txt_visdrone(self.target)
        image_targets = self.clean_targets(video_targets, idx)
        image_targets["is_crowd"] = 0
        boxes = image_targets[["bbox_left", "bbox_top", "right", "bottom"]]

        boxes = boxes.astype('float32')

        boxes = torch.as_tensor(boxes.values, dtype=torch.float32)
        labels = torch.as_tensor(image_targets.object_category.astype('int64').values, dtype=torch.int64)
        crowd = torch.as_tensor(image_targets.is_crowd.values, dtype=torch.int64)

        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = crowd

        if self.preprocessing is not None:
            img, target = self.preprocessing(img, target)

        return img, target

    def __len__(self):
        return len(self.imgs)

    def clean_targets(self, targets, idx):

        targets = self.targetsToDataframe(targets)
        targets = targets[(targets.object_category != "0")]
        targets = targets[(targets.frame_index == str(idx+1))]

        targets.bbox_top = targets.bbox_top.astype('float32')
        targets.bbox_height = targets.bbox_height.astype('float32')
        targets.bbox_left = targets.bbox_left.astype('float32')
        targets.bbox_width = targets.bbox_width.astype('float32')

        targets["bottom"] = targets.bbox_top + targets.bbox_height
        targets["right"] = targets.bbox_left + targets.bbox_width

        return targets
    
    def targetsToDataframe(self, array):
        columns = [
          "frame_index",
          "target_id",
          "bbox_left",
          "bbox_top",
          "bbox_width",
          "bbox_height",
          "score",
          "object_category",
          "truncation",
          "oclusion"
        ]
        return pd.DataFrame(data=array,columns=columns)

class AllVisDroneVideos(VisDroneVideo):
    def __init__(self,root, targets_path, preprocessing = None, imgs = None):
      super().__init__(root, targets_path, preprocessing, imgs)
      self.targets = sorted(listdir(Path(targets_path)), key=lambda x: x.lstrip("_"))

    def __len__(self):
      return super().__len__()

    def get_video_name(self, image_path):
      return image_path.stem[:-8] + ".txt", int(image_path.stem[-7:]) -1

    def __getitem__(self, idx):
        img_path = Path(self.root).joinpath(self.imgs[idx])
        img = Image.open(img_path).convert("RGB")

        video_name, image_idx = self.get_video_name(img_path)

        video_targets = Utils.read_txt_visdrone(Path(self.target).joinpath(video_name))
        image_targets = self.clean_targets(video_targets, image_idx)
        image_targets["is_crowd"] = 0
        boxes = image_targets[["bbox_left", "bbox_top", "right", "bottom"]]

        boxes = boxes.astype('float32')

        boxes = torch.as_tensor(boxes.values, dtype=torch.float32)
        labels = torch.as_tensor(image_targets.object_category.astype('int64').values, dtype=torch.int64)
        crowd = torch.as_tensor(image_targets.is_crowd.values, dtype=torch.int64)

        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = crowd

        if self.preprocessing is not None:
            img, target = self.preprocessing(img, target)

        return img, target

    def get_video_from_idx(self,idx):

      video_lengths = [269, 58, 118, 501, 181, 85, 217, 97, 361, 361,
 516, 1255, 398, 412, 213, 256, 261, 307, 348, 225, 421, 680, 341, 768, 721,
 677, 725, 616, 548, 116, 680, 872, 962, 547, 508, 1424, 500, 210, 346, 556, 
 414, 230, 185, 403, 632, 127, 426, 369, 196, 277, 196, 691, 421, 219, 462,296]
      
      for i in range(len(video_lengths)):
        if idx<video_lengths[i]:
          return i, idx
        else:
          idx -= video_lengths[i]
      return len(video_lengths), idx

class VisDroneDataset(object):
    def __init__(self, root, preprocessing = None):
        self.root = root
        self.preprocessing = preprocessing
        
        self.videos = sorted(listdir(Path(root).joinpath("sequences")), key=lambda x: x.lstrip("_"))
        self.targets = sorted(listdir(Path(root).joinpath("annotations")), key=lambda x: x.lstrip("_"))
    
    def __getitem__(self, idx):
      return VisDroneVideo(Path(self.root).joinpath("sequences").joinpath(self.videos[idx]),Path(self.root).joinpath("annotations").joinpath(self.targets[idx]), self.preprocessing)
    
    def __len__(self):
        return len(self.videos)

    '''
        Concatenates the images of all videos into a large VisDroneVideo class
        Allows the model to train on a broader sample of data
    

    def all_images(self):
        large_dataset = VisDroneVideo()

        for i in self:
          for j in i[0]:
            print(j)

    '''

# %% [markdown]
# Utils.py

# %%
class Utils():

  @staticmethod
  def to_tensor():
    transforms = []
    # converts the image, a PIL image, into a PyTorch Tensor
    transforms.append(T.ToTensor())
    return T.Compose(transforms)

  @staticmethod
  def read_txt_visdrone(path):
      """
          Input: Path of the txt file with annotations as in the VisDrone dataset\n
          Output: A numpy array containing the information for bounding boxes
      """
      lines = []
      with open(path) as f:
          lines = f.readlines()
          f.close()
      df = []
      for x in lines:
          splitLine = x.split(",")
          splitLine[-1] = splitLine[-1].split("\n")[0]
          df.append(splitLine)
      return df
      
  @staticmethod
  def bottom_right(left,top,width,height):
      """
          Input: co-ordinates for the top left corner of a bounding box and its width and height\n
          Output: co-ordinates for the bottom right corner
      """
      bottom = top + height
      right = left + width
      return right, bottom

  @staticmethod
  def slice(array, start, stop):
    result = []
    for i in range(stop-start):
      result.append(array[start + i])
    return result

# %%
#Training from scratch
#!!! DO NOT USE IF YOU ARE TRAINING FROM CHECKPOINT

model = build_model()
eval = train(model, epochs = 100, train_percentage= .8, gamma=.0001, checkpoints = 5)
# Out:
# Epoch: [0]  [ 0/12]  eta: 0:00:20  lr: 0.000459  loss: 1.0700 (1.0700)  loss_classifier: 0.4201 (0.4201)  loss_box_reg: 0.4610 (0.4610)  loss_objectness: 0.0799 (0.0799)  loss_rpn_box_reg: 0.1089 (0.1089)  time: 1.6951  data: 1.0363  max mem: 7250
# Epoch: [0]  [10/12]  eta: 0:00:01  lr: 0.005000  loss: 1.0700 (1.1202)  loss_classifier: 0.4383 (0.4334)  loss_box_reg: 0.5096 (0.5116)  loss_objectness: 0.0680 (0.0821)  loss_rpn_box_reg: 0.0997 (0.0932)  time: 0.6762  data: 0.1064  max mem: 7250
# Epoch: [0]  [11/12]  eta: 0:00:00  lr: 0.005000  loss: 1.0700 (1.1265)  loss_classifier: 0.4383 (0.4398)  loss_box_reg: 0.4757 (0.5069)  loss_objectness: 0.0680 (0.0848)  loss_rpn_box_reg: 0.0997 (0.0950)  time: 0.6672  data: 0.0986  max mem: 7250
# Epoch: [0] Total time: 0:00:08 (0.6732 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:27  model_time: 0.2324 (0.2324)  evaluator_time: 0.1004 (0.1004)  time: 1.1502  data: 0.8065  max mem: 7250
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1226 (0.1283)  evaluator_time: 0.0374 (0.0533)  time: 0.1917  data: 0.0143  max mem: 7250
# Test: Total time: 0:00:05 (0.2384 s / it)
# Averaged stats: model_time: 0.1226 (0.1283)  evaluator_time: 0.0374 (0.0533)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.172
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.359
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.142
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.403
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.268
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.459
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:21  model_time: 0.2109 (0.2109)  evaluator_time: 0.0910 (0.0910)  time: 0.9092  data: 0.5935  max mem: 7250
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1204 (0.1271)  evaluator_time: 0.0369 (0.0660)  time: 0.1940  data: 0.0132  max mem: 7250
# Test: Total time: 0:00:05 (0.2417 s / it)
# Averaged stats: model_time: 0.1204 (0.1271)  evaluator_time: 0.0369 (0.0660)
# Accumulating evaluation results...
# DONE (t=0.08s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.172
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.359
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.142
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.179
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.403
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.213
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.268
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.459
#  Model Saved

# %%
# Training from checkpoint

#Need to find the last saved model yourself
#Find in drive and copy link into the variable
path = ""
model_states, cur_epoch, arguments = load_checkpoint( path )

modelCP = build_model()
modelCP.load_model_states(model_states)

eval = train(model, epochs = 100, cur_epoch = cur_epoch, train_percentage= .8, gamma=arguments['gamma'], checkpoints = 5)
