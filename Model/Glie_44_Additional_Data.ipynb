# %% [markdown]
# <a href="https://colab.research.google.com/github/POE-DAMERON/Glie-44/blob/main/Model/Glie_44_Additional_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow_hub as hub
from PIL import Image, ImageDraw, ImageFont
from os import path, listdir
from pathlib import Path
import cv2 as cv
from google.colab import drive
import sys
import io
import random


# %matplotlib inline

'''
  Downloads Data from the VisDrone dataset.
  Input is which dataset to download:
    - 0 is the training dataset
    - 1 is the developper testing dataset
    - 2 is the actual challenge testing dataset
    - 3 is the val dataset
'''

def initialize_training(file = 0):
  # !git clone https://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@github.com/POE-DAMERON/Glie-44.git
  drive.mount('/content/drive')

  
  if file == 1:
    # !unzip /content/drive/MyDrive/Glie_44/VisDrone2019-MOT-test-dev.zip
  elif file == 2:
    # !unzip /content/drive/MyDrive/Glie_44/VisDrone2019-MOT-test-challenge.zip
  elif file == 3:
    # !unzip /content/drive/MyDrive/Glie_44/VisDrone2019-MOT-val.zip
  else:
    # !unzip /content/drive/MyDrive/Glie_44/VisDrone2019-MOT-train.zip

initialize_training()
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000132.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000133.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000134.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000135.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000136.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000137.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000138.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000139.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000140.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000141.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000142.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000143.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000144.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000145.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000146.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000147.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000148.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000149.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000150.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000151.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000152.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000153.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000154.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000155.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000156.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000157.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000158.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000159.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000160.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000161.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000162.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000163.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000164.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000165.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000166.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000167.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000168.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000169.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000170.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000171.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000172.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000173.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000174.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000175.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000176.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000177.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000178.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000179.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000180.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000181.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000182.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000183.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000184.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000185.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000186.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000187.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000188.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000189.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000190.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000191.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000192.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000193.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000194.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000195.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000196.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000197.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000198.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000199.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000200.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000201.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000202.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000203.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000204.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000205.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000206.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000207.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000208.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000209.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000210.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000211.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000212.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000213.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000214.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000215.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000216.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000217.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000218.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000219.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000220.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000221.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000222.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000223.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000224.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000225.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000226.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000227.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000228.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000229.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_00000_v_0000230.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000001.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000002.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000003.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000004.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000005.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000006.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000007.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000008.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000009.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000010.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000011.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000012.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000013.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000014.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000015.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000016.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000017.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000018.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000019.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000020.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000021.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000022.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000023.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000024.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000025.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000026.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000027.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000028.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000029.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000030.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000031.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000032.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000033.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000034.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000035.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000036.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000037.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000038.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000039.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000040.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000041.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000042.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000043.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000044.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000045.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000046.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000047.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000048.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000049.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000050.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000051.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000052.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000053.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000054.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000055.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000056.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000057.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000058.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000059.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000060.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000061.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000062.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000063.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000064.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000065.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000066.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000067.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000068.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000069.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000070.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000071.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000072.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000073.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000074.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000075.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000076.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000077.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000078.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000079.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000080.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000081.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000082.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000083.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000084.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000085.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000086.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000087.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000088.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000089.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000090.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000091.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000092.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000093.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000094.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000095.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000096.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000097.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000098.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000099.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000100.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000101.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000102.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000103.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000104.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000105.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000106.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000107.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000108.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000109.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000110.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000111.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000112.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000113.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000114.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000115.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000116.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000117.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000118.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000119.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000120.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000121.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000122.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000123.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000124.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000125.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000126.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000127.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000128.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000129.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000130.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000131.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000132.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000133.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000134.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000135.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000136.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000137.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000138.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000139.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000140.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000141.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000142.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000143.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000144.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000145.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000146.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000147.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000148.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000149.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000150.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000151.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000152.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000153.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000154.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000155.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000156.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000157.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000158.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000159.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000160.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000161.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000162.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000163.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000164.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000165.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000166.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000167.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000168.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000169.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000170.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000171.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000172.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000173.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000174.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000175.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000176.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000177.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000178.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000179.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000180.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000181.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000182.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000183.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000184.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000308_01380_v_0000185.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000001.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000002.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000003.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000004.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000005.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000006.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000007.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000008.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000009.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000010.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000011.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000012.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000013.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000014.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000015.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000016.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000017.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000018.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000019.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000020.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000021.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000022.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000023.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000024.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000025.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000026.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000027.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000028.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000029.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000030.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000031.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000032.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000033.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000034.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000035.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000036.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000037.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000038.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000039.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000040.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000041.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000042.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000043.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000044.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000045.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000046.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000047.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000048.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000049.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000050.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000051.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000052.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000053.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000054.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000055.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000056.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000057.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000058.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000059.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000060.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000061.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000062.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000063.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000064.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000065.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000066.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000067.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000068.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000069.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000070.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000071.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000072.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000073.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000074.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000075.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000076.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000077.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000078.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000079.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000080.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000081.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000082.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000083.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000084.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000085.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000086.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000087.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000088.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000089.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000090.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000091.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000092.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000093.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000094.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000095.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000096.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000097.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000098.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000099.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000100.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000101.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000102.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000103.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000104.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000105.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000106.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000107.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000108.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000109.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000110.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000111.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000112.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000113.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000114.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000115.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000116.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000117.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000118.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000119.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000120.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000121.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000122.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000123.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000124.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000125.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000126.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000127.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000128.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000129.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000130.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000131.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000132.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000133.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000134.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000135.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000136.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000137.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000138.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000139.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000140.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000141.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000142.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000143.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000144.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000145.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000146.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000147.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000148.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000149.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000150.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000151.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000152.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000153.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000154.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000155.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000156.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000157.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000158.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000159.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000160.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000161.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000162.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000163.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000164.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000165.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000166.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000167.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000168.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000169.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000170.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000171.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000172.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000173.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000174.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000175.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000176.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000177.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000178.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000179.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000180.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000181.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000182.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000183.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000184.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000185.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000186.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000187.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000188.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000189.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000190.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000191.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000192.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000193.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000194.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000195.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000196.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000197.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000198.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000199.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000200.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000201.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000202.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000203.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000204.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000205.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000206.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000207.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000208.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000209.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000210.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000211.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000212.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000213.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000214.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000215.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000216.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000217.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000218.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000219.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000220.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000221.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000222.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000223.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000224.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000225.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000226.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000227.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000228.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000229.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000230.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000231.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000232.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000233.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000234.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000235.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000236.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000237.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000238.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000239.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000240.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000241.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000242.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000243.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000244.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000245.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000246.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000247.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000248.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000249.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000250.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000251.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000252.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000253.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000254.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000255.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000256.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000257.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000258.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000259.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000260.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000261.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000262.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000263.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000264.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000265.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000266.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000267.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000268.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000269.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000270.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000271.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000272.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000273.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000274.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000275.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000276.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000277.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000278.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000279.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000280.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000281.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000282.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000283.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000284.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000285.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000286.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000287.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000288.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000289.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000290.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000291.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000292.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000293.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000294.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000295.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000296.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000297.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000298.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000299.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000300.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000301.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000302.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000303.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000304.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000305.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000306.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000307.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000308.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000309.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000310.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000311.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000312.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000313.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000314.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000315.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000316.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000317.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000318.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000319.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000320.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000321.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000309_00000_v_0000322.jpg
# ...
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000096.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000097.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000098.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000099.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000100.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000101.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000102.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000103.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000104.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000105.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000106.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000107.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000108.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000109.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000110.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000111.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000112.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000113.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000114.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000115.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000116.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000117.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000118.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000119.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000120.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000121.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000122.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000123.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000124.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000125.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000126.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000127.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000128.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000129.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000130.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000131.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000132.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000133.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000134.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000135.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000136.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000137.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000138.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000139.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000140.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000141.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000142.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000143.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000144.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000145.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000146.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000147.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000148.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000149.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000150.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000151.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000152.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000153.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000154.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000155.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000156.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000157.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000158.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000159.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000160.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000161.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000162.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000163.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000164.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000165.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000166.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000167.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000168.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000169.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000170.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000171.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000172.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000173.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000174.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000175.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000176.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000177.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000178.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000179.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000180.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000181.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000182.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000183.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000184.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000185.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000186.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000187.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000188.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000189.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000190.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000191.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000192.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000193.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000194.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000195.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000196.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000197.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000198.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000199.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000200.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000201.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000202.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000203.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000204.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000205.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000206.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000207.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000208.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000209.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000210.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000211.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000212.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000213.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000214.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000215.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000216.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000217.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000218.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000219.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000220.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000221.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000222.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000223.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000224.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000225.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000226.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000227.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000228.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000229.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000230.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000231.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000232.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000233.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000234.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000235.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000236.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000237.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000238.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000239.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000240.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000241.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000242.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000243.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000244.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000245.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000246.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000247.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000248.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000249.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000250.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000251.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000252.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000253.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000254.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000255.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000256.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000257.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000258.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000259.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000260.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000261.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000262.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000263.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000264.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000265.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000266.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000267.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000268.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000269.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000270.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000271.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000272.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000273.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000274.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000275.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000276.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000277.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000278.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000279.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000280.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000281.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000282.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000283.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000284.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000285.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000286.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000287.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000288.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000289.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000290.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000291.jpg
#  extracting: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000292.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000293.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000294.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000295.jpg
#   inflating: VisDrone2019-MOT-train/sequences/uav0000366_00001_v_0000296.jpg
#   inflating: VisDrone2019-MOT-train/updateDatabase.py

# %% [markdown]
# **New Model using Pytorch**

# %% [markdown]
# Main.py

# %%
# %%shell
#
# git clone https://github.com/pytorch/vision.git
# cd vision
# git checkout v0.3.0
#
# cp references/detection/utils.py ../
# cp references/detection/transforms.py ../
# cp references/detection/coco_eval.py ../
# cp references/detection/engine.py ../
# cp references/detection/coco_utils.py ../
# Out:
# Cloning into 'vision'...
# remote: Enumerating objects: 25495, done.
# remote: Counting objects: 100% (2964/2964), done.
# remote: Compressing objects: 100% (814/814), done.
# remote: Total 25495 (delta 2206), reused 2760 (delta 2094), pack-reused 22531
# Receiving objects: 100% (25495/25495), 34.56 MiB | 26.67 MiB/s, done.
# Resolving deltas: 100% (18905/18905), done.
# Note: checking out 'v0.3.0'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at be376084 version check against PyTorch's CUDA version

# %%
import torch
from engine import train_one_epoch, evaluate
import utils
import os
import pandas as pd
from torchvision.transforms import functional as F
from pathlib import Path
import csv
import time
import json

def get_results(evaluator):
  old_stdout = sys.stdout
  sys.stdout = buffer = io.StringIO()

  result = str(evaluator.coco_eval)
  test = evaluator.coco_eval.items()
  for iou_type, coco_eval in test:
    print("IoU metric: {}".format(iou_type))
    try:
      print(coco_eval)
    except:
      pass

  sys.stdout = old_stdout

  return buffer.getvalue()

def add_to_record(arguments, output, is_saved = False, path_to_saved_model = ''):

  with open('drive/MyDrive/training.csv', 'a', newline='') as f:
    writer = csv.writer(f)

    #writer.writerow(['Saved', 'path_to_saved_model', 'number_of_epochs', 'batch_size', 'optimizer', 'learning_rate', 'weight_decay', 'momentum', 'lr_scheduler_step_size', 'lr_scheduler_gamma', 'output'])
    writer.writerow([is_saved, path_to_saved_model, arguments['number_of_epochs'], arguments['batch_size'], arguments['optimizer'], arguments['lr'], arguments['weight_decay'], arguments['momentum'], arguments['lr_scheduler_step_size'], arguments['lr_scheduler_gamma'], output])


"""
  saving the model will add it to the record
"""

def save_model(model, evaluator, arguments, path = ''):

  """
      saves the model and adds to the csv records

      2 methods :
        - saving the whole model
        - saving the weights and info
  """

  if path == '':
    path = 'drive/MyDrive/Models/model-' + str(int(time.time())) + '.pth'

  torch.save(model,path) 

  #torch.save(model.state_dict(), path)
  add_to_record(arguments = arguments, output = evaluator, is_saved = True, path_to_saved_model = path)
  
def load_model(path):

  model = torch.load(path)

  """
    model = Model()
    model.load_state_dict(torch.load(path))
  """

  return model

def save_checkpoints(dicti, path = 'drive/MyDrive/Checkpoints/checkpoint.txt'):
  with open(path, 'w') as f:
    f.write(json.dumps(dicti))

def load_checkpoints(path = 'drive/MyDrive/Checkpoints/checkpoint.txt'):
  dicti = {}
  with open(path, 'r') as f:
    dicti = json.loads(f.read())
  return dicti

def get_arguments(train_percentage, epochs, batch_size, optimizer,
                            lr, momentum, weight_decay, step_size, gamma):
  
  arguments = {}

  arguments['train_percentage'] = train_percentage
  if (optimizer == 'adam'):
    arguments['optimizer'] = optimizer
    arguments['momentum'] = ''
  else:
    arguments['optimizer'] = 'sgd'
    arguments['momentum'] = momentum
  arguments['lr'] = lr
  arguments['weight_decay'] = weight_decay
  arguments['lr_scheduler_step_size'] = step_size
  arguments['lr_scheduler_gamma'] = gamma
  arguments['number_of_epochs'] = epochs
  arguments['batch_size'] = batch_size

  return arguments

def train_videos(path_to_saved_model = '', train_percentage = .8, test_size = -1,
          train_size = -1, batch_size = 2, epochs = 10, optimizer='sgd',
          lr = 0.005, momentum = 0.9, weight_decay= 0.0005, step_size = 3,
          gamma = 0.1, preprocessing = Utils.to_tensor()):
  
  arguments = get_arguments(train_percentage, epochs, batch_size, optimizer,
                            lr, momentum, weight_decay, step_size, gamma)
  
  if torch.cuda.is_available():
    device = torch.device('cuda')
  else:
    device = torch.device('cpu')
  
  x = VisDroneDataset(Path().absolute().joinpath('VisDrone2019-MOT-train'), preprocessing)
  testing_data = torch.utils.data.DataLoader(x[0])

  for i in range(len(x)):

    print("\n-----------------------------\nVideo {} / {}\n".format(i+1, len(x)))

    X = x[i]

    if train_size == -1:
      train_sz = int(len(X) * train_percentage)
    else:
      train_sz = train_size
      
    x_train, x_test = torch.utils.data.random_split(X, [train_sz, len(X) - train_sz])

    if test_size != -1:
      x_test = Utils.slice(x_test, 0, test_size)

    data_loader = torch.utils.data.DataLoader(
          x_train, batch_size=batch_size, shuffle=True, num_workers=2,
          collate_fn=utils.collate_fn)
    
    data_loader_test = torch.utils.data.DataLoader(
      x_test, batch_size=1, shuffle=False, num_workers=2,
      collate_fn=utils.collate_fn)
    
    testing_data = data_loader_test
    
    if str(path_to_saved_model) == '':
      model = build_model()
    else:
      model = load_model(path_to_saved_model)

    model.to(device)

    params = [p for p in model.parameters() if p.requires_grad]

    if (optimizer == 'adam'):
      optim = torch.optim.Adam(params, lr=lr, weight_decay=weight_decay)
    else:
      optim = torch.optim.SGD(params, lr=lr,
                              momentum=momentum, weight_decay=weight_decay)

    lr_scheduler = torch.optim.lr_scheduler.StepLR(optim,
                                                    step_size=step_size,
                                                    gamma=gamma)

    for epoch in range(epochs):
          train_one_epoch(model, optim, data_loader, device, epoch, print_freq=10)
          lr_scheduler.step()
          evaluate(model, testing_data, device=device)
  
  return model, evaluate(model, testing_data, device=device), arguments

def train(path_to_saved_model = '', train_percentage = .8, test_percentage = -1,
          test_size = -1, train_size = -1, batch_size = 2, epochs = 10, cur_epoch=0, optimizer='sgd',
          lr = 0.005, momentum = 0.9, weight_decay= 0.0005, step_size = 3,
          gamma = 0.1, checkpoints=-1, load_checkpoint=False, preprocessing = Utils.to_tensor()):
  
  arguments = get_arguments(train_percentage, epochs, batch_size, optimizer,
                            lr, momentum, weight_decay, step_size, gamma)
  
  if torch.cuda.is_available():
    device = torch.device('cuda')
  else:
    device = torch.device('cpu')
  
  X = AllVisDroneVideos(Path().absolute().joinpath('VisDrone2019-MOT-train').joinpath("sequences"), Path().absolute().joinpath('VisDrone2019-MOT-train').joinpath("annotations"), preprocessing)

  
    
  if str(path_to_saved_model) == '':
    model = build_model()
  else:
    model = load_model(path_to_saved_model)

  if load_checkpoint:
    checkpoint = load_checkpoints()
    gamma = checkpoint['gamma']
    cur_epoch = checkpoint['cur_epoch']

  model.to(device)

  params = [p for p in model.parameters() if p.requires_grad]

  if (optimizer == 'adam'):
    optim = torch.optim.Adam(params, lr=lr, weight_decay=weight_decay)
  else:
    optim = torch.optim.SGD(params, lr=lr,
                              momentum=momentum, weight_decay=weight_decay)

  lr_scheduler = torch.optim.lr_scheduler.StepLR(optim,
                                                    step_size=step_size,
                                                    gamma=gamma)

  for epoch in range(cur_epoch + 1,epochs):
    
    """
      Shuffles the data
    """

    if train_size == -1:
      train_sz = int(len(X) * train_percentage)
    else:
      train_sz = train_size
    
    if test_percentage == -1:
        test_sz = len(X) - train_sz
    else:
        test_sz = int(len(X) * min(1,max(0, test_percentage)))

    #x_train, x_test, x_overflow = torch.utils.data.random_split(X, [train_sz, test_sz , len(X) - train_sz - test_sz])

    random.shuffle(X.imgs)

    x_train = AllVisDroneVideos(Path().absolute().joinpath('VisDrone2019-MOT-train').joinpath("sequences"), Path().absolute().joinpath('VisDrone2019-MOT-train').joinpath("annotations"), preprocessing, X.imgs[:train_sz])
    x_test = AllVisDroneVideos(Path().absolute().joinpath('VisDrone2019-MOT-train').joinpath("sequences"), Path().absolute().joinpath('VisDrone2019-MOT-train').joinpath("annotations"), preprocessing, X.imgs[train_sz:train_sz + test_sz])

    if test_size != -1:
      x_test = Utils.slice(x_test, 0, test_size)

    data_loader = torch.utils.data.DataLoader(
        x_train, batch_size=batch_size, shuffle=True, num_workers=2,
        collate_fn=utils.collate_fn)
      
    data_loader_test = torch.utils.data.DataLoader(
        x_test, batch_size=1, shuffle=False, num_workers=2,
        collate_fn=utils.collate_fn)
    
    train_one_epoch(model, optim, data_loader, device, epoch, print_freq=10)
    print('\n---------\nTRAIN ONE EPOCH FINISHED\n')
    lr_scheduler.step()
    #evaluate(model, data_loader_test, device=device)
    results = get_results(evaluate(model, data_loader_test, device=device))
    if checkpoints != -1 and epoch % checkpoints == 0:
      save_model(model, results, arguments, path_to_saved_model)
      save_checkpoints({'cur_epoch': epoch, 'gamma': gamma})
      print('\nModel Saved\n')
  
  return model, results, arguments

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator

def build_model(num_classes = 12):
  model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
  in_features = model.roi_heads.box_predictor.cls_score.in_features
  model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

  """
  backbone = torchvision.models.mobilenet_v2(pretrained=True).features
  backbone.out_channels = 1280

  anchor_generator = AnchorGenerator(sizes=((32, 64, 128, 256, 512),),
                                    aspect_ratios=((0.5, 1.0, 2.0),))

  roi_pooler = torchvision.ops.MultiScaleRoIAlign(featmap_names=['0'],
                                                  output_size=7,
                                                  sampling_ratio=2)
  return FasterRCNN(backbone,
                    num_classes=num_classes,
                    rpn_anchor_generator=anchor_generator,
                    box_roi_pool=roi_pooler)
  """
  return model

# %%
class VisDroneVideo(object):
    def __init__(self ,root, target_path, preprocessing = None, imgs = None):
        self.root = str(root)
        self.preprocessing = preprocessing
        if (imgs != None):
          self.imgs = imgs
        else:
          self.imgs = sorted(listdir(Path(root)), key=lambda x: x.lstrip("_"))
        self.target = target_path

    def __getitem__(self, idx):

        img_path = Path(self.root).joinpath(self.imgs[idx])
        img = Image.open(img_path).convert("RGB")

        video_targets = Utils.read_txt_visdrone(self.target)
        image_targets = self.clean_targets(video_targets, idx)
        image_targets["is_crowd"] = 0
        boxes = image_targets[["bbox_left", "bbox_top", "right", "bottom"]]

        boxes = boxes.astype('float32')

        boxes = torch.as_tensor(boxes.values, dtype=torch.float32)
        labels = torch.as_tensor(image_targets.object_category.astype('int64').values, dtype=torch.int64)
        crowd = torch.as_tensor(image_targets.is_crowd.values, dtype=torch.int64)

        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = crowd

        if self.preprocessing is not None:
            img = self.preprocessing(img)

        return img, target

    def __len__(self):
        return len(self.imgs)

    def clean_targets(self, targets, idx):

        targets = self.targetsToDataframe(targets)
        targets = targets[(targets.object_category != "0")]
        targets = targets[(targets.frame_index == str(idx+1))]

        targets.bbox_top = targets.bbox_top.astype('float32')
        targets.bbox_height = targets.bbox_height.astype('float32')
        targets.bbox_left = targets.bbox_left.astype('float32')
        targets.bbox_width = targets.bbox_width.astype('float32')

        targets["bottom"] = targets.bbox_top + targets.bbox_height
        targets["right"] = targets.bbox_left + targets.bbox_width

        return targets
    
    def targetsToDataframe(self, array):
        columns = [
          "frame_index",
          "target_id",
          "bbox_left",
          "bbox_top",
          "bbox_width",
          "bbox_height",
          "score",
          "object_category",
          "truncation",
          "oclusion"
        ]
        return pd.DataFrame(data=array,columns=columns)

class AllVisDroneVideos(VisDroneVideo):
    def __init__(self,root, targets_path, preprocessing = None, imgs = None):
      super().__init__(root, targets_path, preprocessing, imgs)
      self.targets = sorted(listdir(Path(targets_path)), key=lambda x: x.lstrip("_"))

    def __len__(self):
      return super().__len__()

    def get_video_name(self, image_path):
      return image_path.stem[:-8] + ".txt", int(image_path.stem[-7:]) -1

    def __getitem__(self, idx):
        img_path = Path(self.root).joinpath(self.imgs[idx])
        img = Image.open(img_path).convert("RGB")

        video_name, image_idx = self.get_video_name(img_path)

        video_targets = Utils.read_txt_visdrone(Path(self.target).joinpath(video_name))
        image_targets = self.clean_targets(video_targets, image_idx)
        image_targets["is_crowd"] = 0
        boxes = image_targets[["bbox_left", "bbox_top", "right", "bottom"]]

        boxes = boxes.astype('float32')

        boxes = torch.as_tensor(boxes.values, dtype=torch.float32)
        labels = torch.as_tensor(image_targets.object_category.astype('int64').values, dtype=torch.int64)
        crowd = torch.as_tensor(image_targets.is_crowd.values, dtype=torch.int64)

        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = crowd

        if self.preprocessing is not None:
            img = self.preprocessing(img)

        return img, target

    def get_video_from_idx(self,idx):

      video_lengths = [269, 58, 118, 501, 181, 85, 217, 97, 361, 361,
 516, 1255, 398, 412, 213, 256, 261, 307, 348, 225, 421, 680, 341, 768, 721,
 677, 725, 616, 548, 116, 680, 872, 962, 547, 508, 1424, 500, 210, 346, 556, 
 414, 230, 185, 403, 632, 127, 426, 369, 196, 277, 196, 691, 421, 219, 462,296]
      
      for i in range(len(video_lengths)):
        if idx<video_lengths[i]:
          return i, idx
        else:
          idx -= video_lengths[i]
      return len(video_lengths), idx

class VisDroneDataset(object):
    def __init__(self, root, preprocessing = None):
        self.root = root
        self.preprocessing = preprocessing
        
        self.videos = sorted(listdir(Path(root).joinpath("sequences")), key=lambda x: x.lstrip("_"))
        self.targets = sorted(listdir(Path(root).joinpath("annotations")), key=lambda x: x.lstrip("_"))
    
    def __getitem__(self, idx):
      return VisDroneVideo(Path(self.root).joinpath("sequences").joinpath(self.videos[idx]),Path(self.root).joinpath("annotations").joinpath(self.targets[idx]), self.preprocessing)
    
    def __len__(self):
        return len(self.videos)

    '''
        Concatenates the images of all videos into a large VisDroneVideo class
        Allows the model to train on a broader sample of data
    

    def all_images(self):
        large_dataset = VisDroneVideo()

        for i in self:
          for j in i[0]:
            print(j)

    '''

# %% [markdown]
# Utils.py

# %%
import torchvision
class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms

    def __call__(self, image, target):
        for t in self.transforms:
            if t == T.ToTensor():
              image, target = t(image, target)
            else:
              image = t(image)
        return image, target

class Utils():

  @staticmethod
  def to_tensor():
    transforms = []
    # converts the image, a PIL image, into a PyTorch Tensor
    transforms.append(torchvision.transforms.ToTensor())
    return torchvision.transforms.Compose(transforms)

  @staticmethod
  def read_txt_visdrone(path):
      """
          Input: Path of the txt file with annotations as in the VisDrone dataset\n
          Output: A numpy array containing the information for bounding boxes
      """
      lines = []
      with open(path) as f:
          lines = f.readlines()
          f.close()
      df = []
      for x in lines:
          splitLine = x.split(",")
          splitLine[-1] = splitLine[-1].split("\n")[0]
          df.append(splitLine)
      return df

  @staticmethod
  def bottom_right(left,top,width,height):
      """
          Input: co-ordinates for the top left corner of a bounding box and its width and height\n
          Output: co-ordinates for the bottom right corner
      """
      bottom = top + height
      right = left + width
      return right, bottom

  @staticmethod
  def slice(array, start, stop):
    result = []
    for i in range(stop-start):
      result.append(array[start + i])
    return result

# %%
preprocessing =torchvision.transforms.Compose([
           #torchvision.transforms.Resize((300,400)), #Croping the image
           torchvision.transforms.ColorJitter(hue=.05, saturation=.05), #Color Jittering 
           torchvision.transforms.RandomHorizontalFlip(), #Horizontal Flip
           torchvision.transforms.RandomRotation(20), #Random Rotation
           torchvision.transforms.Grayscale(num_output_channels=1), #Greyscalling  the image
           torchvision.transforms.RandomVerticalFlip(p=1), #Vertical Flip
           torchvision.transforms.RandomPerspective(distortion_scale=0.5, p=1, interpolation=3, fill=0), #Random Perspective
           torchvision.transforms.ToTensor()
       ])
eval = train('drive/MyDrive/Glie_44/Models/model.pth', epochs = 100, train_percentage= .001, test_percentage = .001, load_checkpoint=False, checkpoints = -1, preprocessing = preprocessing)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:689: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Epoch: [1]  [ 0/12]  eta: 0:00:32  lr: 0.005000  loss: 8.7476 (8.7476)  loss_classifier: 2.5868 (2.5868)  loss_box_reg: 0.2856 (0.2856)  loss_objectness: 5.3368 (5.3368)  loss_rpn_box_reg: 0.5384 (0.5384)  time: 2.7135  data: 2.0725  max mem: 4746
# Epoch: [1]  [10/12]  eta: 0:00:01  lr: 0.005000  loss: 1.8548 (2.6407)  loss_classifier: 0.7532 (0.7915)  loss_box_reg: 0.0890 (0.1053)  loss_objectness: 0.8125 (1.4376)  loss_rpn_box_reg: 0.2763 (0.3064)  time: 0.8691  data: 0.2909  max mem: 4929
# Epoch: [1]  [11/12]  eta: 0:00:00  lr: 0.005000  loss: 1.8548 (2.5938)  loss_classifier: 0.7532 (0.8008)  loss_box_reg: 0.0767 (0.1013)  loss_objectness: 0.7954 (1.3805)  loss_rpn_box_reg: 0.2763 (0.3112)  time: 0.8426  data: 0.2670  max mem: 4929
# Epoch: [1] Total time: 0:00:10 (0.8484 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:25  model_time: 0.2080 (0.2080)  evaluator_time: 0.0115 (0.0115)  time: 1.0656  data: 0.8432  max mem: 4929
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1298 (0.1326)  evaluator_time: 0.0024 (0.0037)  time: 0.2944  data: 0.1587  max mem: 4929
# Test: Total time: 0:00:07 (0.3254 s / it)
# Averaged stats: model_time: 0.1298 (0.1326)  evaluator_time: 0.0024 (0.0037)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [2]  [ 0/12]  eta: 0:00:26  lr: 0.005000  loss: 3.0632 (3.0632)  loss_classifier: 1.9425 (1.9425)  loss_box_reg: 0.1689 (0.1689)  loss_objectness: 0.6713 (0.6713)  loss_rpn_box_reg: 0.2806 (0.2806)  time: 2.2136  data: 1.5171  max mem: 4929
# Epoch: [2]  [10/12]  eta: 0:00:01  lr: 0.005000  loss: 1.6165 (1.7801)  loss_classifier: 0.6036 (0.6799)  loss_box_reg: 0.1010 (0.1058)  loss_objectness: 0.6830 (0.6851)  loss_rpn_box_reg: 0.2669 (0.3092)  time: 0.8730  data: 0.2869  max mem: 5242
# Epoch: [2]  [11/12]  eta: 0:00:00  lr: 0.005000  loss: 1.6158 (1.7239)  loss_classifier: 0.5499 (0.6461)  loss_box_reg: 0.0859 (0.0984)  loss_objectness: 0.6830 (0.6894)  loss_rpn_box_reg: 0.2621 (0.2900)  time: 0.8457  data: 0.2632  max mem: 5242
# Epoch: [2] Total time: 0:00:10 (0.8514 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:23  model_time: 0.2113 (0.2113)  evaluator_time: 0.0444 (0.0444)  time: 0.9655  data: 0.7077  max mem: 5242
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1295 (0.1389)  evaluator_time: 0.1328 (0.1558)  time: 0.3914  data: 0.0823  max mem: 5242
# Test: Total time: 0:00:10 (0.4246 s / it)
# Averaged stats: model_time: 0.1295 (0.1389)  evaluator_time: 0.1328 (0.1558)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
# Epoch: [3]  [ 0/12]  eta: 0:00:32  lr: 0.005000  loss: 2.0871 (2.0871)  loss_classifier: 0.9810 (0.9810)  loss_box_reg: 0.1785 (0.1785)  loss_objectness: 0.6776 (0.6776)  loss_rpn_box_reg: 0.2500 (0.2500)  time: 2.7210  data: 2.0257  max mem: 5242
# Epoch: [3]  [10/12]  eta: 0:00:01  lr: 0.005000  loss: 1.5406 (1.6472)  loss_classifier: 0.4958 (0.5695)  loss_box_reg: 0.0742 (0.0797)  loss_objectness: 0.6776 (0.6729)  loss_rpn_box_reg: 0.3187 (0.3252)  time: 0.9577  data: 0.3594  max mem: 5370
# Epoch: [3]  [11/12]  eta: 0:00:00  lr: 0.005000  loss: 1.4970 (1.6096)  loss_classifier: 0.4938 (0.5471)  loss_box_reg: 0.0642 (0.0769)  loss_objectness: 0.6761 (0.6701)  loss_rpn_box_reg: 0.2868 (0.3155)  time: 0.9485  data: 0.3544  max mem: 5370
# Epoch: [3] Total time: 0:00:11 (0.9544 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:33  model_time: 0.1851 (0.1851)  evaluator_time: 0.3026 (0.3026)  time: 1.3921  data: 0.9013  max mem: 5370
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1313 (0.1339)  evaluator_time: 0.1279 (0.1356)  time: 0.3832  data: 0.1084  max mem: 5370
# Test: Total time: 0:00:09 (0.4067 s / it)
# Averaged stats: model_time: 0.1313 (0.1339)  evaluator_time: 0.1279 (0.1356)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
# Epoch: [4]  [ 0/12]  eta: 0:00:19  lr: 0.000500  loss: 1.3961 (1.3961)  loss_classifier: 0.3558 (0.3558)  loss_box_reg: 0.0288 (0.0288)  loss_objectness: 0.6647 (0.6647)  loss_rpn_box_reg: 0.3470 (0.3470)  time: 1.5910  data: 0.9854  max mem: 5370
# Epoch: [4]  [10/12]  eta: 0:00:01  lr: 0.000500  loss: 1.5495 (1.4973)  loss_classifier: 0.5247 (0.4773)  loss_box_reg: 0.0672 (0.0692)  loss_objectness: 0.6602 (0.6604)  loss_rpn_box_reg: 0.3035 (0.2904)  time: 0.7982  data: 0.2062  max mem: 5370
# Epoch: [4]  [11/12]  eta: 0:00:00  lr: 0.000500  loss: 1.5063 (1.4980)  loss_classifier: 0.4675 (0.4735)  loss_box_reg: 0.0672 (0.0693)  loss_objectness: 0.6602 (0.6617)  loss_rpn_box_reg: 0.3035 (0.2935)  time: 0.7784  data: 0.1893  max mem: 5370
# Epoch: [4] Total time: 0:00:09 (0.7841 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:29  model_time: 0.1958 (0.1958)  evaluator_time: 0.3454 (0.3454)  time: 1.2108  data: 0.6665  max mem: 5370
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1357 (0.1425)  evaluator_time: 0.1304 (0.1664)  time: 0.3288  data: 0.0540  max mem: 5370
# Test: Total time: 0:00:09 (0.4078 s / it)
# Averaged stats: model_time: 0.1357 (0.1425)  evaluator_time: 0.1304 (0.1664)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [5]  [ 0/12]  eta: 0:00:26  lr: 0.000500  loss: 1.3266 (1.3266)  loss_classifier: 0.4398 (0.4398)  loss_box_reg: 0.0141 (0.0141)  loss_objectness: 0.6548 (0.6548)  loss_rpn_box_reg: 0.2179 (0.2179)  time: 2.1721  data: 1.5628  max mem: 5370
# Epoch: [5]  [10/12]  eta: 0:00:01  lr: 0.000500  loss: 1.4347 (1.5101)  loss_classifier: 0.4372 (0.4939)  loss_box_reg: 0.0354 (0.0619)  loss_objectness: 0.6634 (0.6646)  loss_rpn_box_reg: 0.3022 (0.2897)  time: 0.8519  data: 0.2630  max mem: 5370
# Epoch: [5]  [11/12]  eta: 0:00:00  lr: 0.000500  loss: 1.4347 (1.5245)  loss_classifier: 0.4372 (0.5095)  loss_box_reg: 0.0354 (0.0599)  loss_objectness: 0.6634 (0.6647)  loss_rpn_box_reg: 0.2979 (0.2904)  time: 0.8289  data: 0.2417  max mem: 5370
# Epoch: [5] Total time: 0:00:10 (0.8348 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:51  model_time: 0.1959 (0.1959)  evaluator_time: 0.4975 (0.4975)  time: 2.1637  data: 1.4650  max mem: 5370
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1280 (0.1339)  evaluator_time: 0.0757 (0.1322)  time: 0.3197  data: 0.0746  max mem: 5370
# Test: Total time: 0:00:09 (0.3973 s / it)
# Averaged stats: model_time: 0.1280 (0.1339)  evaluator_time: 0.0757 (0.1322)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
# Epoch: [6]  [ 0/12]  eta: 0:00:24  lr: 0.000500  loss: 1.7060 (1.7060)  loss_classifier: 0.5981 (0.5981)  loss_box_reg: 0.1218 (0.1218)  loss_objectness: 0.6479 (0.6479)  loss_rpn_box_reg: 0.3382 (0.3382)  time: 2.0322  data: 1.4424  max mem: 5370
# Epoch: [6]  [10/12]  eta: 0:00:01  lr: 0.000500  loss: 1.6474 (1.5936)  loss_classifier: 0.5812 (0.5407)  loss_box_reg: 0.0856 (0.0846)  loss_objectness: 0.6473 (0.6482)  loss_rpn_box_reg: 0.3276 (0.3201)  time: 0.8857  data: 0.3032  max mem: 5441
# Epoch: [6]  [11/12]  eta: 0:00:00  lr: 0.000500  loss: 1.5398 (1.5623)  loss_classifier: 0.5127 (0.5262)  loss_box_reg: 0.0581 (0.0811)  loss_objectness: 0.6429 (0.6459)  loss_rpn_box_reg: 0.3035 (0.3091)  time: 0.8586  data: 0.2781  max mem: 5441
# Epoch: [6] Total time: 0:00:10 (0.8646 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:17  model_time: 0.2144 (0.2144)  evaluator_time: 0.0815 (0.0815)  time: 0.7419  data: 0.4438  max mem: 5441
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1309 (0.1384)  evaluator_time: 0.1052 (0.1732)  time: 0.4036  data: 0.0996  max mem: 5441
# Test: Total time: 0:00:10 (0.4529 s / it)
# Averaged stats: model_time: 0.1309 (0.1384)  evaluator_time: 0.1052 (0.1732)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
# Epoch: [7]  [ 0/12]  eta: 0:00:29  lr: 0.000050  loss: 1.8986 (1.8986)  loss_classifier: 0.6580 (0.6580)  loss_box_reg: 0.0947 (0.0947)  loss_objectness: 0.6957 (0.6957)  loss_rpn_box_reg: 0.4502 (0.4502)  time: 2.4224  data: 1.7840  max mem: 5441
# Epoch: [7]  [10/12]  eta: 0:00:01  lr: 0.000050  loss: 1.4310 (1.4491)  loss_classifier: 0.4545 (0.4827)  loss_box_reg: 0.0738 (0.0715)  loss_objectness: 0.6535 (0.6522)  loss_rpn_box_reg: 0.2665 (0.2426)  time: 0.8824  data: 0.2900  max mem: 5441
# Epoch: [7]  [11/12]  eta: 0:00:00  lr: 0.000050  loss: 1.2613 (1.4108)  loss_classifier: 0.4334 (0.4590)  loss_box_reg: 0.0448 (0.0660)  loss_objectness: 0.6445 (0.6511)  loss_rpn_box_reg: 0.2195 (0.2346)  time: 0.8551  data: 0.2661  max mem: 5441
# Epoch: [7] Total time: 0:00:10 (0.8617 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:22  model_time: 0.1989 (0.1989)  evaluator_time: 0.0635 (0.0635)  time: 0.9224  data: 0.6569  max mem: 5441
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1252 (0.1332)  evaluator_time: 0.1043 (0.1074)  time: 0.3301  data: 0.0862  max mem: 5441
# Test: Total time: 0:00:08 (0.3630 s / it)
# Averaged stats: model_time: 0.1252 (0.1332)  evaluator_time: 0.1043 (0.1074)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
# Epoch: [8]  [ 0/12]  eta: 0:00:20  lr: 0.000050  loss: 1.9241 (1.9241)  loss_classifier: 0.8113 (0.8113)  loss_box_reg: 0.1907 (0.1907)  loss_objectness: 0.6670 (0.6670)  loss_rpn_box_reg: 0.2550 (0.2550)  time: 1.6979  data: 1.1096  max mem: 5441
# Epoch: [8]  [10/12]  eta: 0:00:01  lr: 0.000050  loss: 1.4485 (1.4609)  loss_classifier: 0.4823 (0.4762)  loss_box_reg: 0.0408 (0.0637)  loss_objectness: 0.6670 (0.6666)  loss_rpn_box_reg: 0.2550 (0.2545)  time: 0.7994  data: 0.2169  max mem: 5441
# Epoch: [8]  [11/12]  eta: 0:00:00  lr: 0.000050  loss: 1.4485 (1.4864)  loss_classifier: 0.4823 (0.4952)  loss_box_reg: 0.0408 (0.0667)  loss_objectness: 0.6670 (0.6672)  loss_rpn_box_reg: 0.2550 (0.2573)  time: 0.7814  data: 0.1995  max mem: 5441
# Epoch: [8] Total time: 0:00:09 (0.7874 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:28  model_time: 0.1984 (0.1984)  evaluator_time: 0.1282 (0.1282)  time: 1.1805  data: 0.8508  max mem: 5441
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1312 (0.1342)  evaluator_time: 0.1047 (0.1164)  time: 0.3520  data: 0.0994  max mem: 5441
# Test: Total time: 0:00:09 (0.3805 s / it)
# Averaged stats: model_time: 0.1312 (0.1342)  evaluator_time: 0.1047 (0.1164)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
# Epoch: [9]  [ 0/12]  eta: 0:00:21  lr: 0.000050  loss: 1.4122 (1.4122)  loss_classifier: 0.4399 (0.4399)  loss_box_reg: 0.0273 (0.0273)  loss_objectness: 0.6666 (0.6666)  loss_rpn_box_reg: 0.2783 (0.2783)  time: 1.8046  data: 1.1720  max mem: 5441
# Epoch: [9]  [10/12]  eta: 0:00:01  lr: 0.000050  loss: 1.5201 (1.5927)  loss_classifier: 0.5196 (0.5817)  loss_box_reg: 0.0599 (0.0559)  loss_objectness: 0.6610 (0.6588)  loss_rpn_box_reg: 0.3090 (0.2964)  time: 0.8543  data: 0.2460  max mem: 5441
# Epoch: [9]  [11/12]  eta: 0:00:00  lr: 0.000050  loss: 1.5201 (1.6020)  loss_classifier: 0.5196 (0.5859)  loss_box_reg: 0.0599 (0.0564)  loss_objectness: 0.6610 (0.6620)  loss_rpn_box_reg: 0.3090 (0.2977)  time: 0.8337  data: 0.2290  max mem: 5441
# Epoch: [9] Total time: 0:00:10 (0.8402 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:35  model_time: 0.1954 (0.1954)  evaluator_time: 0.3182 (0.3182)  time: 1.4868  data: 0.9700  max mem: 5441
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1329 (0.1369)  evaluator_time: 0.0547 (0.1057)  time: 0.2920  data: 0.0719  max mem: 5441
# Test: Total time: 0:00:08 (0.3653 s / it)
# Averaged stats: model_time: 0.1329 (0.1369)  evaluator_time: 0.0547 (0.1057)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
# Epoch: [10]  [ 0/12]  eta: 0:00:30  lr: 0.000005  loss: 1.7328 (1.7328)  loss_classifier: 0.6556 (0.6556)  loss_box_reg: 0.1624 (0.1624)  loss_objectness: 0.6466 (0.6466)  loss_rpn_box_reg: 0.2682 (0.2682)  time: 2.5075  data: 1.8287  max mem: 5441
# Epoch: [10]  [10/12]  eta: 0:00:01  lr: 0.000005  loss: 1.4325 (1.4127)  loss_classifier: 0.4350 (0.4428)  loss_box_reg: 0.0457 (0.0579)  loss_objectness: 0.6637 (0.6686)  loss_rpn_box_reg: 0.2712 (0.2434)  time: 0.8194  data: 0.2110  max mem: 5441
# Epoch: [10]  [11/12]  eta: 0:00:00  lr: 0.000005  loss: 1.3442 (1.4070)  loss_classifier: 0.4287 (0.4416)  loss_box_reg: 0.0457 (0.0597)  loss_objectness: 0.6630 (0.6661)  loss_rpn_box_reg: 0.2682 (0.2395)  time: 0.7986  data: 0.1936  max mem: 5441
# Epoch: [10] Total time: 0:00:09 (0.8047 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:20  model_time: 0.2031 (0.2031)  evaluator_time: 0.0306 (0.0306)  time: 0.8363  data: 0.5994  max mem: 5441
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1375 (0.1371)  evaluator_time: 0.1043 (0.1365)  time: 0.3505  data: 0.0809  max mem: 5441
# Test: Total time: 0:00:09 (0.3898 s / it)
# Averaged stats: model_time: 0.1375 (0.1371)  evaluator_time: 0.1043 (0.1365)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
# Epoch: [11]  [ 0/12]  eta: 0:00:25  lr: 0.000005  loss: 1.4272 (1.4272)  loss_classifier: 0.3573 (0.3573)  loss_box_reg: 0.0635 (0.0635)  loss_objectness: 0.6954 (0.6954)  loss_rpn_box_reg: 0.3110 (0.3110)  time: 2.1640  data: 1.5447  max mem: 5441
# Epoch: [11]  [10/12]  eta: 0:00:01  lr: 0.000005  loss: 1.4272 (1.4817)  loss_classifier: 0.4461 (0.4791)  loss_box_reg: 0.0327 (0.0492)  loss_objectness: 0.6810 (0.6696)  loss_rpn_box_reg: 0.2714 (0.2838)  time: 0.9086  data: 0.3153  max mem: 5441
# Epoch: [11]  [11/12]  eta: 0:00:00  lr: 0.000005  loss: 1.4272 (1.4835)  loss_classifier: 0.4461 (0.4836)  loss_box_reg: 0.0327 (0.0496)  loss_objectness: 0.6602 (0.6679)  loss_rpn_box_reg: 0.2670 (0.2824)  time: 0.8806  data: 0.2892  max mem: 5441
# Epoch: [11] Total time: 0:00:10 (0.8866 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:35  model_time: 0.1948 (0.1948)  evaluator_time: 0.0309 (0.0309)  time: 1.4968  data: 1.2651  max mem: 5441
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1283 (0.1360)  evaluator_time: 0.0978 (0.1023)  time: 0.3422  data: 0.1065  max mem: 5441
# Test: Total time: 0:00:09 (0.3879 s / it)
# Averaged stats: model_time: 0.1283 (0.1360)  evaluator_time: 0.0978 (0.1023)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
# Epoch: [12]  [ 0/12]  eta: 0:00:28  lr: 0.000005  loss: 1.3900 (1.3900)  loss_classifier: 0.5140 (0.5140)  loss_box_reg: 0.0006 (0.0006)  loss_objectness: 0.6163 (0.6163)  loss_rpn_box_reg: 0.2590 (0.2590)  time: 2.3869  data: 1.6730  max mem: 5441
# Epoch: [12]  [10/12]  eta: 0:00:01  lr: 0.000005  loss: 1.4346 (1.3585)  loss_classifier: 0.4843 (0.4469)  loss_box_reg: 0.0308 (0.0383)  loss_objectness: 0.6400 (0.6477)  loss_rpn_box_reg: 0.2325 (0.2256)  time: 0.9062  data: 0.2912  max mem: 5441
# Epoch: [12]  [11/12]  eta: 0:00:00  lr: 0.000005  loss: 1.4346 (1.3859)  loss_classifier: 0.4843 (0.4593)  loss_box_reg: 0.0308 (0.0399)  loss_objectness: 0.6400 (0.6486)  loss_rpn_box_reg: 0.2325 (0.2380)  time: 0.8793  data: 0.2672  max mem: 5441
# Epoch: [12] Total time: 0:00:10 (0.8853 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:21  model_time: 0.2158 (0.2158)  evaluator_time: 0.0896 (0.0896)  time: 0.9163  data: 0.6078  max mem: 5441
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1367 (0.1400)  evaluator_time: 0.0691 (0.1008)  time: 0.3418  data: 0.0954  max mem: 5441
# Test: Total time: 0:00:08 (0.3655 s / it)
# Averaged stats: model_time: 0.1367 (0.1400)  evaluator_time: 0.0691 (0.1008)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
# Epoch: [13]  [ 0/12]  eta: 0:00:30  lr: 0.000001  loss: 1.5614 (1.5614)  loss_classifier: 0.6320 (0.6320)  loss_box_reg: 0.0480 (0.0480)  loss_objectness: 0.6434 (0.6434)  loss_rpn_box_reg: 0.2381 (0.2381)  time: 2.5491  data: 1.8561  max mem: 5441
# Epoch: [13]  [10/12]  eta: 0:00:01  lr: 0.000001  loss: 1.5017 (1.4888)  loss_classifier: 0.4985 (0.5076)  loss_box_reg: 0.0480 (0.0678)  loss_objectness: 0.6579 (0.6584)  loss_rpn_box_reg: 0.2562 (0.2550)  time: 0.8997  data: 0.2992  max mem: 5441
# Epoch: [13]  [11/12]  eta: 0:00:00  lr: 0.000001  loss: 1.5017 (1.4980)  loss_classifier: 0.4985 (0.5090)  loss_box_reg: 0.0480 (0.0686)  loss_objectness: 0.6579 (0.6612)  loss_rpn_box_reg: 0.2562 (0.2592)  time: 0.8729  data: 0.2749  max mem: 5441
# Epoch: [13] Total time: 0:00:10 (0.8794 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:48  model_time: 0.1761 (0.1761)  evaluator_time: 0.6785 (0.6785)  time: 2.0306  data: 1.1709  max mem: 5441
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1317 (0.1356)  evaluator_time: 0.1128 (0.1851)  time: 0.3541  data: 0.0562  max mem: 5441
# Test: Total time: 0:00:10 (0.4255 s / it)
# Averaged stats: model_time: 0.1317 (0.1356)  evaluator_time: 0.1128 (0.1851)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
# Epoch: [14]  [ 0/12]  eta: 0:00:17  lr: 0.000001  loss: 1.3418 (1.3418)  loss_classifier: 0.4062 (0.4062)  loss_box_reg: 0.0338 (0.0338)  loss_objectness: 0.6887 (0.6887)  loss_rpn_box_reg: 0.2130 (0.2130)  time: 1.4615  data: 0.8918  max mem: 5441
# Epoch: [14]  [10/12]  eta: 0:00:01  lr: 0.000001  loss: 1.4854 (1.5217)  loss_classifier: 0.4586 (0.5188)  loss_box_reg: 0.0359 (0.0419)  loss_objectness: 0.6836 (0.6721)  loss_rpn_box_reg: 0.2819 (0.2889)  time: 0.8600  data: 0.2587  max mem: 5441
# Epoch: [14]  [11/12]  eta: 0:00:00  lr: 0.000001  loss: 1.4854 (1.5308)  loss_classifier: 0.4586 (0.5251)  loss_box_reg: 0.0359 (0.0476)  loss_objectness: 0.6764 (0.6724)  loss_rpn_box_reg: 0.2760 (0.2857)  time: 0.8366  data: 0.2379  max mem: 5441
# Epoch: [14] Total time: 0:00:10 (0.8427 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:13  model_time: 0.1922 (0.1922)  evaluator_time: 0.0032 (0.0032)  time: 0.5572  data: 0.3597  max mem: 5441
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1340 (0.1377)  evaluator_time: 0.1241 (0.1528)  time: 0.4047  data: 0.1064  max mem: 5441
# Test: Total time: 0:00:10 (0.4243 s / it)
# Averaged stats: model_time: 0.1340 (0.1377)  evaluator_time: 0.1241 (0.1528)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
# Epoch: [15]  [ 0/12]  eta: 0:00:18  lr: 0.000001  loss: 1.4764 (1.4764)  loss_classifier: 0.4935 (0.4935)  loss_box_reg: 0.1376 (0.1376)  loss_objectness: 0.6420 (0.6420)  loss_rpn_box_reg: 0.2033 (0.2033)  time: 1.5300  data: 0.9075  max mem: 5441
# Epoch: [15]  [10/12]  eta: 0:00:01  lr: 0.000001  loss: 1.4366 (1.4435)  loss_classifier: 0.4499 (0.4683)  loss_box_reg: 0.0536 (0.0586)  loss_objectness: 0.6609 (0.6558)  loss_rpn_box_reg: 0.2734 (0.2608)  time: 0.8451  data: 0.2474  max mem: 5441
# Epoch: [15]  [11/12]  eta: 0:00:00  lr: 0.000001  loss: 1.3870 (1.4238)  loss_classifier: 0.4390 (0.4582)  loss_box_reg: 0.0500 (0.0555)  loss_objectness: 0.6602 (0.6536)  loss_rpn_box_reg: 0.2176 (0.2564)  time: 0.8222  data: 0.2276  max mem: 5441
# Epoch: [15] Total time: 0:00:09 (0.8288 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:19  model_time: 0.2089 (0.2089)  evaluator_time: 0.0179 (0.0179)  time: 0.8067  data: 0.5766  max mem: 5441
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1355 (0.1392)  evaluator_time: 0.0704 (0.0789)  time: 0.3380  data: 0.1192  max mem: 5441
# Test: Total time: 0:00:08 (0.3509 s / it)
# Averaged stats: model_time: 0.1355 (0.1392)  evaluator_time: 0.0704 (0.0789)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
# Epoch: [16]  [ 0/12]  eta: 0:00:30  lr: 0.000000  loss: 1.8049 (1.8049)  loss_classifier: 0.8275 (0.8275)  loss_box_reg: 0.0442 (0.0442)  loss_objectness: 0.6437 (0.6437)  loss_rpn_box_reg: 0.2895 (0.2895)  time: 2.5180  data: 1.8221  max mem: 5441
# Epoch: [16]  [10/12]  eta: 0:00:01  lr: 0.000000  loss: 1.5352 (1.4892)  loss_classifier: 0.4698 (0.4995)  loss_box_reg: 0.0397 (0.0546)  loss_objectness: 0.6437 (0.6507)  loss_rpn_box_reg: 0.2832 (0.2844)  time: 0.8286  data: 0.2245  max mem: 5441
# Epoch: [16]  [11/12]  eta: 0:00:00  lr: 0.000000  loss: 1.4241 (1.4752)  loss_classifier: 0.4296 (0.4782)  loss_box_reg: 0.0386 (0.0514)  loss_objectness: 0.6437 (0.6523)  loss_rpn_box_reg: 0.2832 (0.2933)  time: 0.8066  data: 0.2061  max mem: 5441
# Epoch: [16] Total time: 0:00:09 (0.8132 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:17  model_time: 0.2020 (0.2020)  evaluator_time: 0.1003 (0.1003)  time: 0.7203  data: 0.4160  max mem: 5441
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1302 (0.1367)  evaluator_time: 0.1014 (0.1379)  time: 0.3605  data: 0.0928  max mem: 5441
# Test: Total time: 0:00:09 (0.4014 s / it)
# Averaged stats: model_time: 0.1302 (0.1367)  evaluator_time: 0.1014 (0.1379)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
# Epoch: [17]  [ 0/12]  eta: 0:00:20  lr: 0.000000  loss: 1.3829 (1.3829)  loss_classifier: 0.3907 (0.3907)  loss_box_reg: 0.0334 (0.0334)  loss_objectness: 0.6691 (0.6691)  loss_rpn_box_reg: 0.2896 (0.2896)  time: 1.6906  data: 1.0760  max mem: 5441
# Epoch: [17]  [10/12]  eta: 0:00:01  lr: 0.000000  loss: 1.5115 (1.5506)  loss_classifier: 0.5061 (0.5352)  loss_box_reg: 0.0704 (0.0839)  loss_objectness: 0.6615 (0.6609)  loss_rpn_box_reg: 0.2645 (0.2706)  time: 0.8301  data: 0.2252  max mem: 5441
# Epoch: [17]  [11/12]  eta: 0:00:00  lr: 0.000000  loss: 1.4983 (1.5463)  loss_classifier: 0.5061 (0.5369)  loss_box_reg: 0.0508 (0.0794)  loss_objectness: 0.6615 (0.6626)  loss_rpn_box_reg: 0.2336 (0.2674)  time: 0.8093  data: 0.2072  max mem: 5441
# Epoch: [17] Total time: 0:00:09 (0.8155 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:26  model_time: 0.2010 (0.2010)  evaluator_time: 0.2507 (0.2507)  time: 1.1141  data: 0.6592  max mem: 5441
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1268 (0.1341)  evaluator_time: 0.1179 (0.1407)  time: 0.3265  data: 0.0649  max mem: 5441
# Test: Total time: 0:00:08 (0.3746 s / it)
# Averaged stats: model_time: 0.1268 (0.1341)  evaluator_time: 0.1179 (0.1407)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.005
# Epoch: [18]  [ 0/12]  eta: 0:00:24  lr: 0.000000  loss: 1.4240 (1.4240)  loss_classifier: 0.4040 (0.4040)  loss_box_reg: 0.0444 (0.0444)  loss_objectness: 0.6697 (0.6697)  loss_rpn_box_reg: 0.3060 (0.3060)  time: 2.0804  data: 1.4647  max mem: 5441
# Epoch: [18]  [10/12]  eta: 0:00:01  lr: 0.000000  loss: 1.4977 (1.5703)  loss_classifier: 0.4640 (0.5557)  loss_box_reg: 0.0805 (0.0947)  loss_objectness: 0.6693 (0.6689)  loss_rpn_box_reg: 0.2466 (0.2510)  time: 0.8551  data: 0.2503  max mem: 5469
# Epoch: [18]  [11/12]  eta: 0:00:00  lr: 0.000000  loss: 1.4877 (1.5634)  loss_classifier: 0.4640 (0.5535)  loss_box_reg: 0.0516 (0.0894)  loss_objectness: 0.6693 (0.6717)  loss_rpn_box_reg: 0.2254 (0.2488)  time: 0.8323  data: 0.2301  max mem: 5469
# Epoch: [18] Total time: 0:00:10 (0.8384 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:13  model_time: 0.2048 (0.2048)  evaluator_time: 0.0144 (0.0144)  time: 0.5519  data: 0.3306  max mem: 5469
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1295 (0.1393)  evaluator_time: 0.0974 (0.1201)  time: 0.3231  data: 0.0761  max mem: 5469
# Test: Total time: 0:00:08 (0.3702 s / it)
# Averaged stats: model_time: 0.1295 (0.1393)  evaluator_time: 0.0974 (0.1201)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
# Epoch: [19]  [ 0/12]  eta: 0:00:19  lr: 0.000000  loss: 1.5967 (1.5967)  loss_classifier: 0.6861 (0.6861)  loss_box_reg: 0.0671 (0.0671)  loss_objectness: 0.6214 (0.6214)  loss_rpn_box_reg: 0.2220 (0.2220)  time: 1.6541  data: 1.0330  max mem: 5469
# Epoch: [19]  [10/12]  eta: 0:00:01  lr: 0.000000  loss: 1.3693 (1.5197)  loss_classifier: 0.5096 (0.5135)  loss_box_reg: 0.0578 (0.0615)  loss_objectness: 0.6446 (0.6443)  loss_rpn_box_reg: 0.2220 (0.3004)  time: 0.8845  data: 0.2720  max mem: 5469
# Epoch: [19]  [11/12]  eta: 0:00:00  lr: 0.000000  loss: 1.3693 (1.5444)  loss_classifier: 0.5096 (0.5337)  loss_box_reg: 0.0578 (0.0643)  loss_objectness: 0.6446 (0.6475)  loss_rpn_box_reg: 0.2220 (0.2989)  time: 0.8596  data: 0.2496  max mem: 5469
# Epoch: [19] Total time: 0:00:10 (0.8656 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:23  model_time: 0.2164 (0.2164)  evaluator_time: 0.1304 (0.1304)  time: 0.9668  data: 0.6165  max mem: 5469
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1248 (0.1346)  evaluator_time: 0.0772 (0.0971)  time: 0.3362  data: 0.1106  max mem: 5469
# Test: Total time: 0:00:08 (0.3601 s / it)
# Averaged stats: model_time: 0.1248 (0.1346)  evaluator_time: 0.0772 (0.0971)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
# Epoch: [20]  [ 0/12]  eta: 0:00:30  lr: 0.000000  loss: 1.8510 (1.8510)  loss_classifier: 0.7634 (0.7634)  loss_box_reg: 0.1480 (0.1480)  loss_objectness: 0.6570 (0.6570)  loss_rpn_box_reg: 0.2825 (0.2825)  time: 2.5601  data: 1.8509  max mem: 5469
# Epoch: [20]  [10/12]  eta: 0:00:01  lr: 0.000000  loss: 1.5515 (1.4763)  loss_classifier: 0.5196 (0.4864)  loss_box_reg: 0.0634 (0.0732)  loss_objectness: 0.6570 (0.6586)  loss_rpn_box_reg: 0.2825 (0.2582)  time: 0.8747  data: 0.2578  max mem: 5469
# Epoch: [20]  [11/12]  eta: 0:00:00  lr: 0.000000  loss: 1.5515 (1.4993)  loss_classifier: 0.5196 (0.4933)  loss_box_reg: 0.0634 (0.0795)  loss_objectness: 0.6512 (0.6580)  loss_rpn_box_reg: 0.2825 (0.2686)  time: 0.8499  data: 0.2369  max mem: 5469
# Epoch: [20] Total time: 0:00:10 (0.8561 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:26  model_time: 0.1802 (0.1802)  evaluator_time: 0.2810 (0.2810)  time: 1.0976  data: 0.6324  max mem: 5469
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1355 (0.1379)  evaluator_time: 0.0976 (0.1403)  time: 0.3516  data: 0.0945  max mem: 5469
# Test: Total time: 0:00:09 (0.3907 s / it)
# Averaged stats: model_time: 0.1355 (0.1379)  evaluator_time: 0.0976 (0.1403)
# Accumulating evaluation results...
# DONE (t=0.07s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
# Epoch: [21]  [ 0/12]  eta: 0:00:17  lr: 0.000000  loss: 1.3065 (1.3065)  loss_classifier: 0.3412 (0.3412)  loss_box_reg: 0.0646 (0.0646)  loss_objectness: 0.6316 (0.6316)  loss_rpn_box_reg: 0.2692 (0.2692)  time: 1.4670  data: 0.8638  max mem: 5469
# Epoch: [21]  [10/12]  eta: 0:00:01  lr: 0.000000  loss: 1.4240 (1.4211)  loss_classifier: 0.4371 (0.4524)  loss_box_reg: 0.0646 (0.0604)  loss_objectness: 0.6527 (0.6527)  loss_rpn_box_reg: 0.2692 (0.2556)  time: 0.7630  data: 0.1531  max mem: 5469
# Epoch: [21]  [11/12]  eta: 0:00:00  lr: 0.000000  loss: 1.4240 (1.4405)  loss_classifier: 0.4371 (0.4660)  loss_box_reg: 0.0489 (0.0594)  loss_objectness: 0.6527 (0.6532)  loss_rpn_box_reg: 0.2692 (0.2619)  time: 0.7486  data: 0.1410  max mem: 5469
# Epoch: [21] Total time: 0:00:09 (0.7549 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:14  model_time: 0.2187 (0.2187)  evaluator_time: 0.0035 (0.0035)  time: 0.5855  data: 0.3614  max mem: 5469
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1244 (0.1357)  evaluator_time: 0.0751 (0.0802)  time: 0.3451  data: 0.1220  max mem: 5469
# Test: Total time: 0:00:08 (0.3490 s / it)
# Averaged stats: model_time: 0.1244 (0.1357)  evaluator_time: 0.0751 (0.0802)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
# ...
# Epoch: [93]  [ 0/12]  eta: 0:00:30  lr: 0.000000  loss: 1.5280 (1.5280)  loss_classifier: 0.5253 (0.5253)  loss_box_reg: 0.0434 (0.0434)  loss_objectness: 0.6639 (0.6639)  loss_rpn_box_reg: 0.2953 (0.2953)  time: 2.5616  data: 1.9218  max mem: 5530
# Epoch: [93]  [10/12]  eta: 0:00:01  lr: 0.000000  loss: 1.5120 (1.4646)  loss_classifier: 0.5079 (0.5036)  loss_box_reg: 0.0434 (0.0552)  loss_objectness: 0.6493 (0.6510)  loss_rpn_box_reg: 0.2585 (0.2548)  time: 0.8061  data: 0.2005  max mem: 5530
# Epoch: [93]  [11/12]  eta: 0:00:00  lr: 0.000000  loss: 1.4877 (1.4621)  loss_classifier: 0.4402 (0.4983)  loss_box_reg: 0.0337 (0.0534)  loss_objectness: 0.6489 (0.6501)  loss_rpn_box_reg: 0.2585 (0.2603)  time: 0.7870  data: 0.1844  max mem: 5530
# Epoch: [93] Total time: 0:00:09 (0.7934 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:13  model_time: 0.1853 (0.1853)  evaluator_time: 0.0040 (0.0040)  time: 0.5665  data: 0.3750  max mem: 5530
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1329 (0.1347)  evaluator_time: 0.1073 (0.1318)  time: 0.3753  data: 0.1031  max mem: 5530
# Test: Total time: 0:00:09 (0.3846 s / it)
# Averaged stats: model_time: 0.1329 (0.1347)  evaluator_time: 0.1073 (0.1318)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
# Epoch: [94]  [ 0/12]  eta: 0:00:30  lr: 0.000000  loss: 1.1566 (1.1566)  loss_classifier: 0.1840 (0.1840)  loss_box_reg: 0.0342 (0.0342)  loss_objectness: 0.5981 (0.5981)  loss_rpn_box_reg: 0.3403 (0.3403)  time: 2.5833  data: 1.9297  max mem: 5530
# Epoch: [94]  [10/12]  eta: 0:00:01  lr: 0.000000  loss: 1.3576 (1.4043)  loss_classifier: 0.3952 (0.4009)  loss_box_reg: 0.0342 (0.0438)  loss_objectness: 0.6378 (0.6430)  loss_rpn_box_reg: 0.3512 (0.3166)  time: 0.9229  data: 0.3212  max mem: 5530
# Epoch: [94]  [11/12]  eta: 0:00:00  lr: 0.000000  loss: 1.3576 (1.4177)  loss_classifier: 0.3952 (0.4142)  loss_box_reg: 0.0342 (0.0478)  loss_objectness: 0.6378 (0.6463)  loss_rpn_box_reg: 0.3403 (0.3094)  time: 0.8948  data: 0.2951  max mem: 5530
# Epoch: [94] Total time: 0:00:10 (0.9016 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:31  model_time: 0.2110 (0.2110)  evaluator_time: 0.1749 (0.1749)  time: 1.3215  data: 0.9324  max mem: 5530
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1230 (0.1345)  evaluator_time: 0.0882 (0.1384)  time: 0.3992  data: 0.1409  max mem: 5530
# Test: Total time: 0:00:10 (0.4409 s / it)
# Averaged stats: model_time: 0.1230 (0.1345)  evaluator_time: 0.0882 (0.1384)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
# Epoch: [95]  [ 0/12]  eta: 0:00:30  lr: 0.000000  loss: 1.4860 (1.4860)  loss_classifier: 0.5424 (0.5424)  loss_box_reg: 0.0510 (0.0510)  loss_objectness: 0.6350 (0.6350)  loss_rpn_box_reg: 0.2575 (0.2575)  time: 2.5067  data: 1.7907  max mem: 5530
# Epoch: [95]  [10/12]  eta: 0:00:01  lr: 0.000000  loss: 1.5368 (1.5195)  loss_classifier: 0.5110 (0.5325)  loss_box_reg: 0.0516 (0.0715)  loss_objectness: 0.6641 (0.6609)  loss_rpn_box_reg: 0.2714 (0.2546)  time: 0.8677  data: 0.2599  max mem: 5745
# Epoch: [95]  [11/12]  eta: 0:00:00  lr: 0.000000  loss: 1.4860 (1.4980)  loss_classifier: 0.4829 (0.5174)  loss_box_reg: 0.0510 (0.0663)  loss_objectness: 0.6549 (0.6604)  loss_rpn_box_reg: 0.2655 (0.2539)  time: 0.8427  data: 0.2384  max mem: 5745
# Epoch: [95] Total time: 0:00:10 (0.8495 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:41  model_time: 0.1927 (0.1927)  evaluator_time: 0.3253 (0.3253)  time: 1.7167  data: 1.1929  max mem: 5745
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1255 (0.1322)  evaluator_time: 0.1020 (0.1324)  time: 0.3263  data: 0.0860  max mem: 5745
# Test: Total time: 0:00:09 (0.3933 s / it)
# Averaged stats: model_time: 0.1255 (0.1322)  evaluator_time: 0.1020 (0.1324)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.001
# Epoch: [96]  [ 0/12]  eta: 0:00:20  lr: 0.000000  loss: 1.5864 (1.5864)  loss_classifier: 0.5795 (0.5795)  loss_box_reg: 0.0658 (0.0658)  loss_objectness: 0.6183 (0.6183)  loss_rpn_box_reg: 0.3228 (0.3228)  time: 1.6667  data: 1.0483  max mem: 5745
# Epoch: [96]  [10/12]  eta: 0:00:01  lr: 0.000000  loss: 1.6411 (1.6531)  loss_classifier: 0.5795 (0.5492)  loss_box_reg: 0.0698 (0.0894)  loss_objectness: 0.6752 (0.6701)  loss_rpn_box_reg: 0.3228 (0.3445)  time: 0.9202  data: 0.3130  max mem: 5745
# Epoch: [96]  [11/12]  eta: 0:00:00  lr: 0.000000  loss: 1.5864 (1.5947)  loss_classifier: 0.5772 (0.5183)  loss_box_reg: 0.0658 (0.0820)  loss_objectness: 0.6708 (0.6695)  loss_rpn_box_reg: 0.3065 (0.3250)  time: 0.8910  data: 0.2876  max mem: 5745
# Epoch: [96] Total time: 0:00:10 (0.8979 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:24  model_time: 0.2081 (0.2081)  evaluator_time: 0.2109 (0.2109)  time: 1.0159  data: 0.5949  max mem: 5745
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1275 (0.1356)  evaluator_time: 0.0922 (0.1327)  time: 0.3456  data: 0.0874  max mem: 5745
# Test: Total time: 0:00:09 (0.3860 s / it)
# Averaged stats: model_time: 0.1275 (0.1356)  evaluator_time: 0.0922 (0.1327)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.001
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
# Epoch: [97]  [ 0/12]  eta: 0:00:17  lr: 0.000000  loss: 1.3585 (1.3585)  loss_classifier: 0.3944 (0.3944)  loss_box_reg: 0.1210 (0.1210)  loss_objectness: 0.6551 (0.6551)  loss_rpn_box_reg: 0.1880 (0.1880)  time: 1.4499  data: 0.8312  max mem: 5745
# Epoch: [97]  [10/12]  eta: 0:00:01  lr: 0.000000  loss: 1.4210 (1.3932)  loss_classifier: 0.3944 (0.4518)  loss_box_reg: 0.0535 (0.0579)  loss_objectness: 0.6551 (0.6491)  loss_rpn_box_reg: 0.2014 (0.2344)  time: 0.8041  data: 0.2015  max mem: 5745
# Epoch: [97]  [11/12]  eta: 0:00:00  lr: 0.000000  loss: 1.4210 (1.4114)  loss_classifier: 0.3944 (0.4636)  loss_box_reg: 0.0535 (0.0622)  loss_objectness: 0.6551 (0.6499)  loss_rpn_box_reg: 0.2014 (0.2357)  time: 0.7943  data: 0.1940  max mem: 5745
# Epoch: [97] Total time: 0:00:09 (0.8006 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:26  model_time: 0.2135 (0.2135)  evaluator_time: 0.1674 (0.1674)  time: 1.0915  data: 0.7074  max mem: 5745
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1341 (0.1413)  evaluator_time: 0.0940 (0.1693)  time: 0.3261  data: 0.0492  max mem: 5745
# Test: Total time: 0:00:09 (0.4066 s / it)
# Averaged stats: model_time: 0.1341 (0.1413)  evaluator_time: 0.0940 (0.1693)
# Accumulating evaluation results...
# DONE (t=0.06s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.003
# Epoch: [98]  [ 0/12]  eta: 0:00:22  lr: 0.000000  loss: 1.8905 (1.8905)  loss_classifier: 0.6058 (0.6058)  loss_box_reg: 0.1776 (0.1776)  loss_objectness: 0.6707 (0.6707)  loss_rpn_box_reg: 0.4364 (0.4364)  time: 1.8674  data: 1.2295  max mem: 5745
# Epoch: [98]  [10/12]  eta: 0:00:01  lr: 0.000000  loss: 1.4363 (1.4198)  loss_classifier: 0.3883 (0.4080)  loss_box_reg: 0.0462 (0.0622)  loss_objectness: 0.6579 (0.6656)  loss_rpn_box_reg: 0.2588 (0.2841)  time: 0.7624  data: 0.1660  max mem: 5745
# Epoch: [98]  [11/12]  eta: 0:00:00  lr: 0.000000  loss: 1.4123 (1.4192)  loss_classifier: 0.3883 (0.4070)  loss_box_reg: 0.0462 (0.0639)  loss_objectness: 0.6579 (0.6720)  loss_rpn_box_reg: 0.2551 (0.2763)  time: 0.7468  data: 0.1528  max mem: 5745
# Epoch: [98] Total time: 0:00:09 (0.7528 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:23  model_time: 0.1936 (0.1936)  evaluator_time: 0.1421 (0.1421)  time: 0.9797  data: 0.6421  max mem: 5745
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1309 (0.1372)  evaluator_time: 0.1084 (0.1518)  time: 0.4300  data: 0.1424  max mem: 5745
# Test: Total time: 0:00:10 (0.4527 s / it)
# Averaged stats: model_time: 0.1309 (0.1372)  evaluator_time: 0.1084 (0.1518)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.004
# Epoch: [99]  [ 0/12]  eta: 0:00:23  lr: 0.000000  loss: 1.4187 (1.4187)  loss_classifier: 0.3651 (0.3651)  loss_box_reg: 0.0390 (0.0390)  loss_objectness: 0.7191 (0.7191)  loss_rpn_box_reg: 0.2956 (0.2956)  time: 1.9701  data: 1.3627  max mem: 5745
# Epoch: [99]  [10/12]  eta: 0:00:01  lr: 0.000000  loss: 1.4187 (1.4714)  loss_classifier: 0.4115 (0.4737)  loss_box_reg: 0.0618 (0.0707)  loss_objectness: 0.6560 (0.6524)  loss_rpn_box_reg: 0.2631 (0.2746)  time: 0.9520  data: 0.3525  max mem: 5745
# Epoch: [99]  [11/12]  eta: 0:00:00  lr: 0.000000  loss: 1.4187 (1.4792)  loss_classifier: 0.3711 (0.4651)  loss_box_reg: 0.0532 (0.0657)  loss_objectness: 0.6507 (0.6519)  loss_rpn_box_reg: 0.2631 (0.2966)  time: 0.9213  data: 0.3240  max mem: 5745
# Epoch: [99] Total time: 0:00:11 (0.9276 s / it)
#
# ---------
# TRAIN ONE EPOCH FINISHED
#
# creating index...
# index created!
# Test:  [ 0/24]  eta: 0:00:27  model_time: 0.1915 (0.1915)  evaluator_time: 0.2384 (0.2384)  time: 1.1427  data: 0.7097  max mem: 5745
# Test:  [23/24]  eta: 0:00:00  model_time: 0.1245 (0.1343)  evaluator_time: 0.0825 (0.1159)  time: 0.3871  data: 0.1446  max mem: 5745
# Test: Total time: 0:00:10 (0.4321 s / it)
# Averaged stats: model_time: 0.1245 (0.1343)  evaluator_time: 0.0825 (0.1159)
# Accumulating evaluation results...
# DONE (t=0.05s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.002
